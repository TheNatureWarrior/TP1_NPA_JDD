# %% [markdown]
# # Team Project 1
# ## DS160-01
# ### AUTHORS: Naat Ambrosino and Jardin Dantzler
# ### VERSION: 1
# ### SEMESTER: Spring 2022
# ### SUMMARY:
# #### We developed this notebook to....

# %% [markdown]
# #### Pre-work (cleaning up dataset in general)

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import pylab 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('Canada_Hosp1_COVID_Data_At_Admission.csv')
dfx=pd.read_csv('Canada_Hosp1_COVID_Data_At_Admission.csv')

# %%
df
# Out:
#       id                        reason_for_admission  age     sex ethnicity  \
# 0      1                               Fever [R50.9]   74    Male      "[]"
# 1      2                           Pneumonia [J18.9]   61  Female      "[]"
# 2      3                           Pneumonia [J18.9]   58  Female      "[]"
# 3      4  Suspected COVID-19 virus infection [U07.2]   94    Male      "[]"
# 4      5  Febrile respiratory illness [J98.9, R50.9]   91    Male      "[]"
# ..   ...                                         ...  ...     ...       ...
# 503  516                 Shortness of breath [R06.0]   74  Female      "[]"
# 504  517                            COVID-19 [U07.1]   81    Male      "[]"
# 505  519                            COVID-19 [U07.1]   74    Male      "[]"
# 506  521                            COVID-19 [U07.1]   48  Female      "[]"
# 507  522                            COVID-19 [U07.1]   73    Male      "[]"
#
#      ethnicity_other  height  weight  \
# 0                NaN     NaN     NaN
# 1                NaN   154.9    73.6
# 2                NaN     NaN     NaN
# 3                NaN   182.8    66.2
# 4                NaN     NaN     NaN
# ..               ...     ...     ...
# 503              NaN     NaN    55.0
# 504              NaN   158.0    65.0
# 505              NaN     NaN    81.7
# 506              NaN   180.0    95.3
# 507              NaN     NaN     NaN
#
#                                          comorbidities  \
# 0          "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                       "[\"Hypertension\",\"Other\"]"
# 2                                 "[\"Hypertension\"]"
# 3                       "[\"Hypertension\",\"Other\"]"
# 4    "[\"Chronic cardiac disease (not hypertension)...
# ..                                                 ...
# 503                                      "[\"Other\"]"
# 504  "[\"Hypertension\",\"Chronic renal\",\"Diabete...
# 505                     "[\"Hypertension\",\"Other\"]"
# 506                                               "[]"
# 507                                               "[]"
#
#                                    comorbidities_other  ...  pao2  pao2_fio2  \
# 0    GERD (gastroesophageal reflux disease), Dement...  ...   NaN        NaN
# 1    Closed fracture of fifth metatarsal bone, Dive...  ...   NaN        NaN
# 2                                                  NaN  ...   NaN        NaN
# 3    Parkinson's Disease, Back pain, Benign Prostat...  ...   NaN        NaN
# 4    TAVI, Atrial fibrillation, Gastric Reflux, Pac...  ...   NaN        NaN
# ..                                                 ...  ...   ...        ...
# 503  Arthritis, High cholesterol, Hypothyroidism, V...  ...   NaN        NaN
# 504  GERD (gastroesophageal reflux disease), High c...  ...  76.0        1.5
# 505  Dermatitis, Hyponatremia, Irritable bowel synd...  ...   NaN        NaN
# 506                                                NaN  ...   NaN        NaN
# 507                                                NaN  ...   NaN        NaN
#
#        ph high_senstivity_cardiac_troponin  esr  inr ferritin  d_dimer    crp  \
# 0     NaN                              NaN  NaN  1.1      NaN      NaN  223.0
# 1     NaN                              NaN  NaN  1.0      NaN     2354   95.6
# 2     NaN                              NaN  NaN  NaN      NaN      NaN    NaN
# 3     NaN                              NaN  NaN  NaN      NaN      NaN    NaN
# 4     NaN                              NaN  NaN  NaN      NaN      NaN    NaN
# ..    ...                              ...  ...  ...      ...      ...    ...
# 503   NaN                              NaN  NaN  1.1      NaN      NaN    NaN
# 504  7.44                              NaN  NaN  NaN      NaN    >4000    NaN
# 505   NaN                              NaN  NaN  1.5      NaN      NaN    NaN
# 506   NaN                              NaN  NaN  1.0      NaN      428    NaN
# 507   NaN                              NaN  NaN  1.1      NaN     1584    NaN
#
#      hs_crp
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 503     NaN
# 504     NaN
# 505     NaN
# 506     NaN
# 507     NaN
#
# [508 rows x 55 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                508 non-null    int64
#  1   reason_for_admission              508 non-null    object
#  2   age                               508 non-null    int64
#  3   sex                               508 non-null    object
#  4   ethnicity                         508 non-null    object
#  5   ethnicity_other                   0 non-null      float64
#  6   height                            272 non-null    float64
#  7   weight                            358 non-null    float64
#  8   comorbidities                     508 non-null    object
#  9   comorbidities_other               404 non-null    object
#  10  received_covid_vaccine            1 non-null      object
#  11  covid_vaccine                     0 non-null      float64
#  12  medications                       508 non-null    object
#  13  smoking_history                   296 non-null    object
#  14  year_they_quit                    43 non-null     float64
#  15  previous_er_visit_within_14_days  508 non-null    object
#  16  admission_disposition             508 non-null    object
#  17  systolic_blood_pressure           508 non-null    int64
#  18  diastolic_blood_pressure          508 non-null    int64
#  19  heart_rate                        508 non-null    int64
#  20  respiratory_rate                  508 non-null    int64
#  21  oxygen_saturation                 508 non-null    int64
#  22  temperature                       508 non-null    float64
#  23  motor                             506 non-null    float64
#  24  verbal                            506 non-null    float64
#  25  eye                               506 non-null    float64
#  26  intubated                         508 non-null    object
#  27  wbc                               506 non-null    float64
#  28  rbc                               506 non-null    float64
#  29  hemoglobin                        506 non-null    float64
#  30  hematocrit                        506 non-null    float64
#  31  mcv                               506 non-null    float64
#  32  mch                               506 non-null    float64
#  33  mchc                              506 non-null    float64
#  34  rdw                               506 non-null    float64
#  35  platelet_count                    506 non-null    float64
#  36  aptt_aptr                         288 non-null    object
#  37  pt                                315 non-null    float64
#  38  alt                               403 non-null    float64
#  39  ast                               403 non-null    float64
#  40  serum_creatinine                  506 non-null    float64
#  41  sodium                            506 non-null    float64
#  42  potassium                         506 non-null    float64
#  43  total_serum_bilirubin             403 non-null    float64
#  44  lactate                           362 non-null    float64
#  45  pao2                              32 non-null     float64
#  46  pao2_fio2                         23 non-null     float64
#  47  ph                                32 non-null     float64
#  48  high_senstivity_cardiac_troponin  0 non-null      float64
#  49  esr                               5 non-null      float64
#  50  inr                               315 non-null    float64
#  51  ferritin                          20 non-null     float64
#  52  d_dimer                           252 non-null    object
#  53  crp                               142 non-null    float64
#  54  hs_crp                            0 non-null      float64
# dtypes: float64(35), int64(7), object(13)
# memory usage: 218.4+ KB

# %% [markdown]
# Dropping ID as it is just a alternative index (and skips values, its intended to be used to reference a single patient across the different datasets but since we are only using the Data At Admission dataset, the ID column is obsolete), along with the columns that are empty or nearly empty (<=40 non-null values.) We will decide on other columns with much missing data later.

# %%
df.columns
# Out:
# Index(['id', 'reason_for_admission', 'age', 'sex', 'ethnicity',
#        'ethnicity_other', 'height', 'weight', 'comorbidities',
#        'comorbidities_other', 'received_covid_vaccine', 'covid_vaccine',
#        'medications', 'smoking_history', 'year_they_quit',
#        'previous_er_visit_within_14_days', 'admission_disposition',
#        'systolic_blood_pressure', 'diastolic_blood_pressure', 'heart_rate',
#        'respiratory_rate', 'oxygen_saturation', 'temperature', 'motor',
#        'verbal', 'eye', 'intubated', 'wbc', 'rbc', 'hemoglobin', 'hematocrit',
#        'mcv', 'mch', 'mchc', 'rdw', 'platelet_count', 'aptt_aptr', 'pt', 'alt',
#        'ast', 'serum_creatinine', 'sodium', 'potassium',
#        'total_serum_bilirubin', 'lactate', 'pao2', 'pao2_fio2', 'ph',
#        'high_senstivity_cardiac_troponin', 'esr', 'inr', 'ferritin', 'd_dimer',
#        'crp', 'hs_crp'],
#       dtype='object')

# %%
df.drop(['id','ethnicity_other','received_covid_vaccine', 'covid_vaccine',
        'pao2', 'pao2_fio2', 'ph',
       'high_senstivity_cardiac_troponin', 'esr','ferritin','hs_crp'],
       axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   ethnicity                         508 non-null    object
#  4   height                            272 non-null    float64
#  5   weight                            358 non-null    float64
#  6   comorbidities                     508 non-null    object
#  7   comorbidities_other               404 non-null    object
#  8   medications                       508 non-null    object
#  9   smoking_history                   296 non-null    object
#  10  year_they_quit                    43 non-null     float64
#  11  previous_er_visit_within_14_days  508 non-null    object
#  12  admission_disposition             508 non-null    object
#  13  systolic_blood_pressure           508 non-null    int64
#  14  diastolic_blood_pressure          508 non-null    int64
#  15  heart_rate                        508 non-null    int64
#  16  respiratory_rate                  508 non-null    int64
#  17  oxygen_saturation                 508 non-null    int64
#  18  temperature                       508 non-null    float64
#  19  motor                             506 non-null    float64
#  20  verbal                            506 non-null    float64
#  21  eye                               506 non-null    float64
#  22  intubated                         508 non-null    object
#  23  wbc                               506 non-null    float64
#  24  rbc                               506 non-null    float64
#  25  hemoglobin                        506 non-null    float64
#  26  hematocrit                        506 non-null    float64
#  27  mcv                               506 non-null    float64
#  28  mch                               506 non-null    float64
#  29  mchc                              506 non-null    float64
#  30  rdw                               506 non-null    float64
#  31  platelet_count                    506 non-null    float64
#  32  aptt_aptr                         288 non-null    object
#  33  pt                                315 non-null    float64
#  34  alt                               403 non-null    float64
#  35  ast                               403 non-null    float64
#  36  serum_creatinine                  506 non-null    float64
#  37  sodium                            506 non-null    float64
#  38  potassium                         506 non-null    float64
#  39  total_serum_bilirubin             403 non-null    float64
#  40  lactate                           362 non-null    float64
#  41  inr                               315 non-null    float64
#  42  d_dimer                           252 non-null    object
#  43  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(12)
# memory usage: 174.8+ KB

# %% [markdown]
# Noticed earlier that ethnicity seems to have a lot of (if not completely comprised of) "[]" values, and on the website there seemed to be an off value in the sex column. Going to check both of them using .groupby().count to see if we should keep ethnicity at all and whether theres a typo in sex.

# %%
df.ethnicity.groupby(df.ethnicity).count()
# Out:
# ethnicity
# "[]"    508
# Name: ethnicity, dtype: int64

# %% [markdown]
# Ethnicity column has no actual values for all intents and purposes. Dropping.

# %%
df.drop(['ethnicity'],axis=1,inplace=True)

# %%
df.sex.groupby(df.sex).count()
# Out:
# sex
# Female    212
# Male      296
# Name: sex, dtype: int64

# %% [markdown]
# Does not appear to be a typo in sex. Good! Now checking how many columns we still have, along with their datatypes.

# %%
len(df.columns)
# Out:
# 43

# %%
df.head()
# Out:
#                          reason_for_admission  age     sex  height  weight  \
# 0                               Fever [R50.9]   74    Male     NaN     NaN
# 1                           Pneumonia [J18.9]   61  Female   154.9    73.6
# 2                           Pneumonia [J18.9]   58  Female     NaN     NaN
# 3  Suspected COVID-19 virus infection [U07.2]   94    Male   182.8    66.2
# 4  Febrile respiratory illness [J98.9, R50.9]   91    Male     NaN     NaN
#
#                                        comorbidities  \
# 0        "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                     "[\"Hypertension\",\"Other\"]"
# 2                               "[\"Hypertension\"]"
# 3                     "[\"Hypertension\",\"Other\"]"
# 4  "[\"Chronic cardiac disease (not hypertension)...
#
#                                  comorbidities_other  \
# 0  GERD (gastroesophageal reflux disease), Dement...
# 1  Closed fracture of fifth metatarsal bone, Dive...
# 2                                                NaN
# 3  Parkinson's Disease, Back pain, Benign Prostat...
# 4  TAVI, Atrial fibrillation, Gastric Reflux, Pac...
#
#                                          medications smoking_history  \
# 0  "[{\"medications\":\"TYLENOL EXTRA STRENGTH\",...             NaN
# 1  "[{\"medications\":\"CANDESARTAN\",\"dosage\":...             NaN
# 2  "[{\"medications\":\"\",\"dosage\":\"\",\"freq...             NaN
# 3  "[{\"medications\":\"ACETYLSALICYLIC ACID  TAB...             NaN
# 4  "[{\"medications\":\"TRAZODONE\",\"dosage\":\"...       Ex-smoker
#
#    year_they_quit  ...   alt   ast  serum_creatinine  sodium  potassium  \
# 0             NaN  ...  53.0  49.0             165.0   135.0        3.9
# 1             NaN  ...  68.0  68.0              49.0   137.0        3.8
# 2             NaN  ...  52.0  76.0              71.0   135.0        3.7
# 3             NaN  ...   6.0  24.0             146.0   135.0        2.8
# 4             NaN  ...  17.0  26.0             109.0   142.0        3.8
#
#    total_serum_bilirubin  lactate  inr  d_dimer    crp
# 0                   10.0      2.3  1.1      NaN  223.0
# 1                   12.0      1.5  1.0     2354   95.6
# 2                    7.0      1.0  NaN      NaN    NaN
# 3                   10.0      4.5  NaN      NaN    NaN
# 4                   19.0      3.2  NaN      NaN    NaN
#
# [5 rows x 43 columns]

# %%
df.dtypes
# Out:
# reason_for_admission                 object
# age                                   int64
# sex                                  object
# height                              float64
# weight                              float64
# comorbidities                        object
# comorbidities_other                  object
# medications                          object
# smoking_history                      object
# year_they_quit                      float64
# previous_er_visit_within_14_days     object
# admission_disposition                object
# systolic_blood_pressure               int64
# diastolic_blood_pressure              int64
# heart_rate                            int64
# respiratory_rate                      int64
# oxygen_saturation                     int64
# temperature                         float64
# motor                               float64
# verbal                              float64
# eye                                 float64
# intubated                            object
# wbc                                 float64
# rbc                                 float64
# hemoglobin                          float64
# hematocrit                          float64
# mcv                                 float64
# mch                                 float64
# mchc                                float64
# rdw                                 float64
# platelet_count                      float64
# aptt_aptr                            object
# pt                                  float64
# alt                                 float64
# ast                                 float64
# serum_creatinine                    float64
# sodium                              float64
# potassium                           float64
# total_serum_bilirubin               float64
# lactate                             float64
# inr                                 float64
# d_dimer                              object
# crp                                 float64
# dtype: object

# %% [markdown]
# Going to get the pairwise correlation table just to see if theres anything that immmediately stands out at this stage.

# %%
df.corr()
# Out:
#                                age    height    weight  year_they_quit  \
# age                       1.000000 -0.270279 -0.377498       -0.343756
# height                   -0.270279  1.000000  0.467210       -0.022039
# weight                   -0.377498  0.467210  1.000000       -0.100169
# year_they_quit           -0.343756 -0.022039 -0.100169        1.000000
# systolic_blood_pressure   0.069945  0.024319 -0.006880        0.075185
# diastolic_blood_pressure -0.171599  0.099043  0.079176        0.242800
# heart_rate               -0.347154  0.141969  0.098641        0.172657
# respiratory_rate         -0.145326  0.011598  0.078056        0.157459
# oxygen_saturation        -0.030766  0.007100 -0.087124       -0.377551
# temperature              -0.024273  0.051773  0.054604        0.002955
# motor                    -0.125640  0.026314  0.053841       -0.002588
# verbal                   -0.320959  0.091066  0.177266        0.061855
# eye                      -0.135918  0.026608  0.060895       -0.002588
# wbc                       0.024746 -0.067838  0.004816       -0.026063
# rbc                      -0.291152  0.309153  0.220381        0.232738
# hemoglobin               -0.176298  0.324434  0.156123        0.252882
# hematocrit               -0.157195  0.311846  0.196802        0.170562
# mcv                       0.287407 -0.040303 -0.079527       -0.196734
# mch                       0.204531  0.012252 -0.099512       -0.013809
# mchc                     -0.086842  0.105132 -0.089550        0.211032
# rdw                       0.122992 -0.090556  0.080194       -0.110923
# platelet_count           -0.116862 -0.099537  0.043183       -0.331228
# pt                        0.121951  0.199803  0.028663       -0.176305
# alt                      -0.163725  0.121294 -0.001842       -0.011995
# ast                      -0.011269  0.101476 -0.028792        0.051852
# serum_creatinine          0.158276  0.040418 -0.010503       -0.046996
# sodium                    0.168237 -0.001297 -0.059378       -0.148895
# potassium                 0.186950  0.140092 -0.002744        0.015586
# total_serum_bilirubin     0.134210  0.203312  0.051082        0.104789
# lactate                   0.124115  0.123085  0.042740        0.223867
# inr                       0.105539  0.200931  0.022127       -0.173659
# crp                      -0.096656  0.103205  0.271309       -0.491629
#
#                           systolic_blood_pressure  diastolic_blood_pressure  \
# age                                      0.069945                 -0.171599
# height                                   0.024319                  0.099043
# weight                                  -0.006880                  0.079176
# year_they_quit                           0.075185                  0.242800
# systolic_blood_pressure                  1.000000                  0.567449
# diastolic_blood_pressure                 0.567449                  1.000000
# heart_rate                               0.126706                  0.288724
# respiratory_rate                         0.113850                  0.121301
# oxygen_saturation                        0.019313                  0.100811
# temperature                              0.087001                  0.005300
# motor                                   -0.022564                  0.025952
# verbal                                   0.075765                  0.120801
# eye                                      0.054155                  0.074170
# wbc                                      0.041203                  0.023849
# rbc                                      0.017526                  0.185660
# hemoglobin                              -0.035069                  0.146711
# hematocrit                              -0.047107                  0.155338
# mcv                                     -0.091646                 -0.104154
# mch                                     -0.065875                 -0.088354
# mchc                                     0.031300                 -0.002829
# rdw                                      0.000660                  0.011659
# platelet_count                          -0.006034                  0.032775
# pt                                      -0.019106                 -0.026929
# alt                                     -0.004266                  0.043448
# ast                                      0.002675                 -0.006840
# serum_creatinine                         0.022953                 -0.044403
# sodium                                  -0.108161                 -0.013462
# potassium                                0.034805                  0.039455
# total_serum_bilirubin                    0.011347                  0.025469
# lactate                                  0.041900                  0.051104
# inr                                     -0.012608                 -0.019948
# crp                                     -0.005780                 -0.160041
#
#                           heart_rate  respiratory_rate  oxygen_saturation  \
# age                        -0.347154         -0.145326          -0.030766
# height                      0.141969          0.011598           0.007100
# weight                      0.098641          0.078056          -0.087124
# year_they_quit              0.172657          0.157459          -0.377551
# systolic_blood_pressure     0.126706          0.113850           0.019313
# diastolic_blood_pressure    0.288724          0.121301           0.100811
# heart_rate                  1.000000          0.281794          -0.110209
# respiratory_rate            0.281794          1.000000          -0.292778
# oxygen_saturation          -0.110209         -0.292778           1.000000
# temperature                 0.205067          0.123891           0.032976
# motor                      -0.014434         -0.161416           0.067953
# verbal                      0.046615         -0.145739           0.044469
# eye                        -0.037466         -0.149854           0.121552
# wbc                         0.174776          0.238529          -0.141279
# rbc                         0.215016          0.087843          -0.033069
# hemoglobin                  0.156931          0.018122          -0.050266
# hematocrit                  0.156053          0.019237          -0.033935
# mcv                        -0.159242         -0.139434           0.025920
# mch                        -0.119987         -0.120241          -0.000453
# mchc                        0.031018         -0.004053          -0.055528
# rdw                         0.037306          0.048970          -0.055954
# platelet_count              0.095483          0.090541          -0.045569
# pt                         -0.054262          0.004878          -0.057442
# alt                         0.104361          0.102044          -0.014962
# ast                         0.020194          0.065757          -0.075452
# serum_creatinine           -0.107036         -0.046695           0.044824
# sodium                     -0.005217         -0.018047           0.074685
# potassium                  -0.109494         -0.065051           0.072773
# total_serum_bilirubin      -0.009321          0.128252          -0.110496
# lactate                     0.151708          0.244511          -0.312522
# inr                        -0.051685          0.005740          -0.043497
# crp                         0.061270          0.398590          -0.293848
#
#                           temperature  ...        pt       alt       ast  \
# age                         -0.024273  ...  0.121951 -0.163725 -0.011269
# height                       0.051773  ...  0.199803  0.121294  0.101476
# weight                       0.054604  ...  0.028663 -0.001842 -0.028792
# year_they_quit               0.002955  ... -0.176305 -0.011995  0.051852
# systolic_blood_pressure      0.087001  ... -0.019106 -0.004266  0.002675
# diastolic_blood_pressure     0.005300  ... -0.026929  0.043448 -0.006840
# heart_rate                   0.205067  ... -0.054262  0.104361  0.020194
# respiratory_rate             0.123891  ...  0.004878  0.102044  0.065757
# oxygen_saturation            0.032976  ... -0.057442 -0.014962 -0.075452
# temperature                  1.000000  ... -0.074575 -0.013911 -0.052316
# motor                       -0.023881  ... -0.015899  0.023867  0.008106
# verbal                      -0.030352  ... -0.051028  0.087963  0.028844
# eye                         -0.056776  ... -0.072604  0.046073  0.032300
# wbc                         -0.010813  ... -0.021079  0.063156  0.023450
# rbc                         -0.012455  ... -0.133356  0.057592  0.004355
# hemoglobin                  -0.041652  ... -0.168566  0.077394  0.019372
# hematocrit                  -0.054257  ... -0.139695  0.049222  0.009303
# mcv                         -0.049427  ...  0.019110 -0.036630  0.000774
# mch                         -0.026132  ... -0.044614  0.010502  0.015254
# mchc                         0.029832  ... -0.153778  0.105851  0.037005
# rdw                          0.093222  ...  0.164959 -0.079378 -0.007602
# platelet_count              -0.162625  ... -0.041689  0.034262 -0.066854
# pt                          -0.074575  ...  1.000000  0.491994  0.717460
# alt                         -0.013911  ...  0.491994  1.000000  0.801665
# ast                         -0.052316  ...  0.717460  0.801665  1.000000
# serum_creatinine             0.035265  ...  0.041278 -0.046927  0.029545
# sodium                      -0.054681  ... -0.017885 -0.072759 -0.124480
# potassium                   -0.110988  ...  0.237370  0.033148  0.158604
# total_serum_bilirubin       -0.076264  ...  0.163872  0.141069  0.184075
# lactate                     -0.164282  ...  0.528962  0.346044  0.486636
# inr                         -0.082416  ...  0.995819  0.522956  0.754879
# crp                         -0.093513  ...  0.112129  0.099615  0.164288
#
#                           serum_creatinine    sodium  potassium  \
# age                               0.158276  0.168237   0.186950
# height                            0.040418 -0.001297   0.140092
# weight                           -0.010503 -0.059378  -0.002744
# year_they_quit                   -0.046996 -0.148895   0.015586
# systolic_blood_pressure           0.022953 -0.108161   0.034805
# diastolic_blood_pressure         -0.044403 -0.013462   0.039455
# heart_rate                       -0.107036 -0.005217  -0.109494
# respiratory_rate                 -0.046695 -0.018047  -0.065051
# oxygen_saturation                 0.044824  0.074685   0.072773
# temperature                       0.035265 -0.054681  -0.110988
# motor                            -0.013332  0.008018  -0.027199
# verbal                           -0.039809 -0.233744  -0.118817
# eye                              -0.009894 -0.161317  -0.055353
# wbc                               0.030615  0.016247  -0.010583
# rbc                              -0.139276 -0.002241  -0.083357
# hemoglobin                       -0.111285  0.037475  -0.078632
# hematocrit                       -0.077974  0.156748  -0.019557
# mcv                               0.139400  0.242407   0.119387
# mch                               0.058343  0.051429   0.013354
# mchc                             -0.137373 -0.381810  -0.212018
# rdw                               0.152155  0.191887   0.046375
# platelet_count                   -0.110290  0.007153  -0.075183
# pt                                0.041278 -0.017885   0.237370
# alt                              -0.046927 -0.072759   0.033148
# ast                               0.029545 -0.124480   0.158604
# serum_creatinine                  1.000000  0.046901   0.268621
# sodium                            0.046901  1.000000   0.013343
# potassium                         0.268621  0.013343   1.000000
# total_serum_bilirubin             0.032493 -0.005484  -0.001757
# lactate                           0.036582 -0.005847   0.131879
# inr                               0.033538 -0.035155   0.236942
# crp                               0.017351 -0.071245  -0.020611
#
#                           total_serum_bilirubin   lactate       inr       crp
# age                                    0.134210  0.124115  0.105539 -0.096656
# height                                 0.203312  0.123085  0.200931  0.103205
# weight                                 0.051082  0.042740  0.022127  0.271309
# year_they_quit                         0.104789  0.223867 -0.173659 -0.491629
# systolic_blood_pressure                0.011347  0.041900 -0.012608 -0.005780
# diastolic_blood_pressure               0.025469  0.051104 -0.019948 -0.160041
# heart_rate                            -0.009321  0.151708 -0.051685  0.061270
# respiratory_rate                       0.128252  0.244511  0.005740  0.398590
# oxygen_saturation                     -0.110496 -0.312522 -0.043497 -0.293848
# temperature                           -0.076264 -0.164282 -0.082416 -0.093513
# motor                                 -0.071683 -0.058265 -0.007640 -0.161642
# verbal                                -0.044287 -0.069271 -0.038121 -0.177972
# eye                                   -0.021045 -0.043331 -0.056941 -0.121488
# wbc                                    0.176354  0.251953 -0.028270  0.442338
# rbc                                    0.087962  0.160507 -0.126381 -0.031943
# hemoglobin                             0.197224  0.174157 -0.161705 -0.115190
# hematocrit                             0.172126  0.195299 -0.134463 -0.114123
# mcv                                    0.092696 -0.011737  0.015642 -0.112231
# mch                                    0.133155 -0.020956 -0.044639 -0.102933
# mchc                                   0.132262 -0.038892 -0.146388 -0.022317
# rdw                                   -0.053935  0.128535  0.148633  0.114420
# platelet_count                        -0.111501  0.032166 -0.043944  0.208520
# pt                                     0.163872  0.528962  0.995819  0.112129
# alt                                    0.141069  0.346044  0.522956  0.099615
# ast                                    0.184075  0.486636  0.754879  0.164288
# serum_creatinine                       0.032493  0.036582  0.033538  0.017351
# sodium                                -0.005484 -0.005847 -0.035155 -0.071245
# potassium                             -0.001757  0.131879  0.236942 -0.020611
# total_serum_bilirubin                  1.000000  0.156743  0.151486  0.108016
# lactate                                0.156743  1.000000  0.550431  0.333353
# inr                                    0.151486  0.550431  1.000000  0.091735
# crp                                    0.108016  0.333353  0.091735  1.000000
#
# [32 rows x 32 columns]

# %% [markdown]
# Well, it seems like most things are very weakly correlated, but there is a correlation coefficient of .996 between inr and pt.  Theres a .8 between alt and ast.  Those might be worth looking into. Surprisingly it seems like age does not have a correlation with an absolute value more than .5, which is noteable and might be worth looking at via pair plots.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     508 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       508 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  aptt_aptr                         288 non-null    object
#  32  pt                                315 non-null    float64
#  33  alt                               403 non-null    float64
#  34  ast                               403 non-null    float64
#  35  serum_creatinine                  506 non-null    float64
#  36  sodium                            506 non-null    float64
#  37  potassium                         506 non-null    float64
#  38  total_serum_bilirubin             403 non-null    float64
#  39  lactate                           362 non-null    float64
#  40  inr                               315 non-null    float64
#  41  d_dimer                           252 non-null    object
#  42  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(11)
# memory usage: 170.8+ KB

# %% [markdown]
# I'm going to look through the of categorical variable columns and drop them if they don't seem useful, edit them if they're messy/hard to work with, or just leave them be. I'll also look through the continuous variables directly related to them, if any (ie, year_they_quit is directly related to smoking_history).

# %%
df.reason_for_admission
# Out:
# 0                                   Fever [R50.9]
# 1                               Pneumonia [J18.9]
# 2                               Pneumonia [J18.9]
# 3      Suspected COVID-19 virus infection [U07.2]
# 4      Febrile respiratory illness [J98.9, R50.9]
#                           ...
# 503                   Shortness of breath [R06.0]
# 504                              COVID-19 [U07.1]
# 505                              COVID-19 [U07.1]
# 506                              COVID-19 [U07.1]
# 507                              COVID-19 [U07.1]
# Name: reason_for_admission, Length: 508, dtype: object

# %%
df.reason_for_admission.groupby(df.reason_for_admission).count()
# Out:
# reason_for_admission
# ARDS (adult respiratory distress syndrome) [J80]                        1
# Acquired respiratory distress syndrome [J80]                            1
# Atypical pneumonia [J18.9]                                              2
# COVID-19 [U07.1]                                                      217
# COVID-19 determined by clinical diagnostic criteria [U07.2]             1
# COVID-19 virus infection [U07.1]                                        2
# COVID-19 with multiple comorbidities [U07.1]                            1
# Coronavirus infection [B34.2]                                           2
# Cough [R05]                                                             2
# Febrile respiratory illness [J98.9, R50.9]                              7
# Fever [R50.9]                                                          21
# Fever of unknown origin [R50.9]                                         1
# Hypoxemia [R09.0]                                                       1
# Hypoxia [R09.0]                                                        20
# Hypoxic [R09.0]                                                         1
# Myalgia [M79.19]                                                        1
# Pneumonia [J18.9]                                                     134
# Pneumonia due to 2019-nCoV [U07.1, J12.8]                               1
# Pneumonia due to COVID-19 virus [U07.1, J12.8]                         40
# Respiratory distress [R06.0]                                            9
# Respiratory failure [J96.99]                                            7
# Respiratory tract infection [J98.8]                                     1
# Shortness of breath [R06.0]                                            25
# Shortness of breath with exposure to COVID-19 virus [R06.0, U07.2]      1
# Suspected COVID-19 virus infection [U07.2]                              7
# Tachypnea [R06.8]                                                       1
# Viral pneumonia [J12.9]                                                 1
# Name: reason_for_admission, dtype: int64

# %% [markdown]
# Reason for admission column has some values that are identical in meaning but use slightly different wording. For example, one observation has the value "Fever of unknown origin [R50.9]" and is thus counted seperately from the 21 observations with the entry "Fever [R50.9]". So, we decided to streamline the values so that if two values are represented by the same code(s) or combination of codes, they will be identical.

# %%
def streamReason(x):
    if '[J80]' in x:
        return 'Acute respiratory distress syndrome'
        #Note: After some research, I found Acquired rds and Adult rds both are alternate names for acute rds, so I used acute instead of acquired or adult.
    elif '[J18.9]' in x:
        return 'Pneumonia'
    elif '[U07.1]' in x:
        return 'COVID-19'
    elif '[U07.2]' in x:
        return 'Probable COVID-19'
    elif '[B34.2]' in x:
        return 'Coronavirus infection'
    elif '[R05]' in x:
        return 'Cough'
    elif '[J98.9, R50.9]' in x:
        return 'Febrile respiratory illness'
    elif '[R50.9]' in x:
        return 'Fever'
    elif '[R09.0]' in x:
        return 'Hypoxemia'
    elif '[M79.19]' in x:
        return 'Myalgia'
    elif '[U07.1, J12.8]' in x:
        return 'Pneumonia due to COVID-19 virus'
    elif '[R06.0]' in x:
        return 'Shortness of breath'
    elif '[R06.0, U07.2]' in x:
        return 'Shortness of breath with exposure to COVID-19 virus'
    elif '[R06.8]' in x:
        return 'Tachypnea'
    elif '[J12.9]' in x:
        return 'Viral pneumonia'
    elif '[J96.99]' in x:
        return 'Respiratory failure'
    elif '[J98.8]' in x:
        return 'Respiratory tract infection'
    else: 
        return x

# %%
#checking if the function works
streamReason('COVID-19 with multiple comorbidities [U07.1]')
#It seems to!
# Out:
# 'COVID-19'

# %%
#dataframe['column to put new values in']=list(map(lambda x: functionToApply(x),dataframe['column for function to reference']))

# %%
df['reason_for_admission']=list(map(lambda x: streamReason(x),df['reason_for_admission']))

# %%
df
# Out:
#             reason_for_admission  age     sex  height  weight  \
# 0                          Fever   74    Male     NaN     NaN
# 1                      Pneumonia   61  Female   154.9    73.6
# 2                      Pneumonia   58  Female     NaN     NaN
# 3              Probable COVID-19   94    Male   182.8    66.2
# 4    Febrile respiratory illness   91    Male     NaN     NaN
# ..                           ...  ...     ...     ...     ...
# 503          Shortness of breath   74  Female     NaN    55.0
# 504                     COVID-19   81    Male   158.0    65.0
# 505                     COVID-19   74    Male     NaN    81.7
# 506                     COVID-19   48  Female   180.0    95.3
# 507                     COVID-19   73    Male     NaN     NaN
#
#                                          comorbidities  \
# 0          "[\"Hypertension\",\"Diabetes\",\"Other\"]"
# 1                       "[\"Hypertension\",\"Other\"]"
# 2                                 "[\"Hypertension\"]"
# 3                       "[\"Hypertension\",\"Other\"]"
# 4    "[\"Chronic cardiac disease (not hypertension)...
# ..                                                 ...
# 503                                      "[\"Other\"]"
# 504  "[\"Hypertension\",\"Chronic renal\",\"Diabete...
# 505                     "[\"Hypertension\",\"Other\"]"
# 506                                               "[]"
# 507                                               "[]"
#
#                                    comorbidities_other  \
# 0    GERD (gastroesophageal reflux disease), Dement...
# 1    Closed fracture of fifth metatarsal bone, Dive...
# 2                                                  NaN
# 3    Parkinson's Disease, Back pain, Benign Prostat...
# 4    TAVI, Atrial fibrillation, Gastric Reflux, Pac...
# ..                                                 ...
# 503  Arthritis, High cholesterol, Hypothyroidism, V...
# 504  GERD (gastroesophageal reflux disease), High c...
# 505  Dermatitis, Hyponatremia, Irritable bowel synd...
# 506                                                NaN
# 507                                                NaN
#
#                                            medications smoking_history  \
# 0    "[{\"medications\":\"TYLENOL EXTRA STRENGTH\",...             NaN
# 1    "[{\"medications\":\"CANDESARTAN\",\"dosage\":...             NaN
# 2    "[{\"medications\":\"\",\"dosage\":\"\",\"freq...             NaN
# 3    "[{\"medications\":\"ACETYLSALICYLIC ACID  TAB...             NaN
# 4    "[{\"medications\":\"TRAZODONE\",\"dosage\":\"...       Ex-smoker
# ..                                                 ...             ...
# 503  "[{\"medications\":\"TYLENOL\",\"dosage\":\"32...      Non-smoker
# 504  "[{\"medications\":\"SYNTHROID\",\"dosage\":\"...             NaN
# 505  "[{\"medications\":\"XANAX\",\"dosage\":\"1\",...      Non-smoker
# 506                                               "[]"             NaN
# 507                                               "[]"             NaN
#
#      year_they_quit  ...    alt   ast  serum_creatinine  sodium  potassium  \
# 0               NaN  ...   53.0  49.0             165.0   135.0        3.9
# 1               NaN  ...   68.0  68.0              49.0   137.0        3.8
# 2               NaN  ...   52.0  76.0              71.0   135.0        3.7
# 3               NaN  ...    6.0  24.0             146.0   135.0        2.8
# 4               NaN  ...   17.0  26.0             109.0   142.0        3.8
# ..              ...  ...    ...   ...               ...     ...        ...
# 503             NaN  ...   30.0  41.0              72.0   131.0        4.1
# 504             NaN  ...  107.0  70.0             148.0   135.0        4.2
# 505             NaN  ...   16.0  54.0              77.0   134.0        3.8
# 506             NaN  ...   18.0  33.0              78.0   133.0        3.9
# 507             NaN  ...   56.0  37.0              79.0   140.0        3.8
#
#      total_serum_bilirubin  lactate  inr  d_dimer    crp
# 0                     10.0      2.3  1.1      NaN  223.0
# 1                     12.0      1.5  1.0     2354   95.6
# 2                      7.0      1.0  NaN      NaN    NaN
# 3                     10.0      4.5  NaN      NaN    NaN
# 4                     19.0      3.2  NaN      NaN    NaN
# ..                     ...      ...  ...      ...    ...
# 503                   10.0      2.3  1.1      NaN    NaN
# 504                   11.0      3.7  NaN    >4000    NaN
# 505                    9.0      NaN  1.5      NaN    NaN
# 506                   11.0      1.4  1.0      428    NaN
# 507                    7.0      NaN  1.1     1584    NaN
#
# [508 rows x 43 columns]

# %%
df.reason_for_admission.groupby(df.reason_for_admission).count()
# Out:
# reason_for_admission
# Acute respiratory distress syndrome                      2
# COVID-19                                               220
# Coronavirus infection                                    2
# Cough                                                    2
# Febrile respiratory illness                              7
# Fever                                                   22
# Hypoxemia                                               22
# Myalgia                                                  1
# Pneumonia                                              136
# Pneumonia due to COVID-19 virus                         41
# Probable COVID-19                                        8
# Respiratory failure                                      7
# Respiratory tract infection                              1
# Shortness of breath                                     34
# Shortness of breath with exposure to COVID-19 virus      1
# Tachypnea                                                1
# Viral pneumonia                                          1
# Name: reason_for_admission, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     508 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       508 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  aptt_aptr                         288 non-null    object
#  32  pt                                315 non-null    float64
#  33  alt                               403 non-null    float64
#  34  ast                               403 non-null    float64
#  35  serum_creatinine                  506 non-null    float64
#  36  sodium                            506 non-null    float64
#  37  potassium                         506 non-null    float64
#  38  total_serum_bilirubin             403 non-null    float64
#  39  lactate                           362 non-null    float64
#  40  inr                               315 non-null    float64
#  41  d_dimer                           252 non-null    object
#  42  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(11)
# memory usage: 170.8+ KB

# %%
df.sex.describe()
# Out:
# count      508
# unique       2
# top       Male
# freq       296
# Name: sex, dtype: object

# %%
df.sex.groupby(df.sex).count()
# Out:
# sex
# Female    212
# Male      296
# Name: sex, dtype: int64

# %%
df.comorbidities.groupby(df.comorbidities).count()
# Out:
# comorbidities
# "[\"Asthma\",\"Diabetes\",\"Other\"]"                              1
# "[\"Asthma\",\"Obesity\",\"Other\"]"                               1
# "[\"Asthma\",\"Other\"]"                                          11
# "[\"Asthma\"]"                                                     5
# "[\"Cancer [active only]\",\"Diabetes\",\"Stroke\",\"Other\"]"     1
#                                                                   ..
# "[\"Pregnancy\"]"                                                  2
# "[\"Rheumatologic disorder\",\"Hematological\",\"Other\"]"         1
# "[\"Rheumatologic disorder\",\"Other\"]"                           1
# "[\"Stroke\",\"Other\"]"                                           2
# "[]"                                                              50
# Name: comorbidities, Length: 137, dtype: int64

# %% [markdown]
# The comorbidities column is very messy. I'm going to remove the following characters from each string: "\[]  Once I remove them, each value should be a list of conditions with each condition seperated by a comma, instead of the mess above. I had to make replacing the quotes a seperate line because for some reason, it really didn't like a quotation mark within apostrophies as a string and kept trying to include the later lines of code as part of the badchar string.

# %%
def cleanComorbid(x):
    badchar="[\]"
    for char in badchar:
        x=x.replace(char,"")
    x=x.replace('"',"")
    x=x.replace(",",", ") #adding space after commas for aesthetic purposes
    return x

# %%
#testing function
cleanComorbid('"[\"Asthma\",\"Diabetes\",\"Other\"]"')
#seems to work!
# Out:
# 'Asthma, Diabetes, Other'

# %%
df['comorbidities']=list(map(lambda x: cleanComorbid(x),df['comorbidities']))

# %%
df.comorbidities.groupby(df.comorbidities).count()
# Out:
# comorbidities
#                                                 50
# Asthma                                           5
# Asthma, Diabetes, Other                          1
# Asthma, Obesity, Other                           1
# Asthma, Other                                   11
#                                                 ..
# Pregnancy                                        2
# Pregnancy, Other                                 2
# Rheumatologic disorder, Hematological, Other     1
# Rheumatologic disorder, Other                    1
# Stroke, Other                                    2
# Name: comorbidities, Length: 137, dtype: int64

# %%
df.comorbidities.describe()
# Out:
# count                     508
# unique                    137
# top       Hypertension, Other
# freq                       56
# Name: comorbidities, dtype: object

# %%
comorbs=list(set(i for i in df.comorbidities))

# %%
comorbs
# Out:
# ['',
#  'Hypertension, Kidney disease, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Diabetes, Other',
#  'Hypertension, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic pulmonary (lung) disease, Kidney disease, Diabetes, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Other',
#  'Obesity',
#  'Hypertension, Chronic renal, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, History of cancer now in remission, Diabetes, Other',
#  'Hypertension, Kidney disease, Stroke, Other',
#  'Hypertension, Asthma, Diabetes, Other',
#  'Hypertension, Asthma, Obesity, Diabetes, Other',
#  'Hypertension, Diabetes, Dementia any etiology, Stroke, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic pulmonary (lung) disease, Diabetes, Other',
#  'Chronic pulmonary (lung) disease, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic pulmonary (lung) disease, Chronic renal, Diabetes, Other',
#  'Hypertension, Asthma, Obesity, Diabetes',
#  'Hypertension, Stroke, Other',
#  'Cancer active only, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Stroke, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic renal, Dementia any etiology, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Kidney disease, Cancer active only, Diabetes, Dementia any etiology, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic renal, Diabetes, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Asthma, Obesity, Diabetes, Dementia any etiology, Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Cancer active only',
#  'Liver disease, Cancer active only, Rheumatologic disorder, Other',
#  'Chronic cardiac disease (not hypertension), Chronic pulmonary (lung) disease, Cancer active only, Dementia any etiology, Stroke, Other',
#  'Hypertension, Asthma, Diabetes, Stroke, Other',
#  'Hypertension, Cancer active only, History of cancer now in remission, Dementia any etiology, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic pulmonary (lung) disease, History of cancer now in remission, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Cancer active only, Other',
#  'Hypertension, Diabetes, Rheumatologic disorder, Hematological, Other',
#  'Hypertension, Obesity, Other',
#  'Chronic cardiac disease (not hypertension), Chronic pulmonary (lung) disease, Chronic renal, Obesity, Other',
#  'Hypertension, Obesity, Diabetes, Other',
#  'Chronic renal, Diabetes',
#  'Rheumatologic disorder, Hematological, Other',
#  'Chronic cardiac disease (not hypertension), Chronic pulmonary (lung) disease, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Obesity, Diabetes, Other',
#  'Hypertension, Chronic renal, Diabetes, Other',
#  'Hypertension, Chronic renal, History of cancer now in remission, Other',
#  'Chronic cardiac disease (not hypertension), Chronic renal, Other',
#  'Rheumatologic disorder, Other',
#  'Chronic pulmonary (lung) disease',
#  'Chronic cardiac disease (not hypertension), Other',
#  'Hypertension, Kidney disease, Diabetes, Other',
#  'Pregnancy',
#  'Hypertension, Chronic neurological disorder, Rheumatologic disorder, Stroke, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Liver disease, History of cancer now in remission, Stroke, Other',
#  'Hypertension',
#  'Asthma, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic renal, Rheumatologic disorder, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Asthma, Stroke, Other',
#  'History of cancer now in remission',
#  'Hypertension, Cancer active only, History of cancer now in remission, Other',
#  'Hypertension, Dementia any etiology, Stroke, Other',
#  'Hypertension, Chronic neurological disorder, Hematological, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Cancer active only, Diabetes, Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Diabetes, Dementia any etiology, Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Obesity, Diabetes, Other',
#  'Kidney disease, Cancer active only, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic pulmonary (lung) disease, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic pulmonary (lung) disease, Asthma, Obesity, Diabetes, Other',
#  'Hypertension, Chronic renal',
#  'Chronic cardiac disease (not hypertension), Stroke, Other',
#  'Hypertension, Kidney disease, Cancer active only, Stroke, Other',
#  'Hypertension, History of cancer now in remission, Dementia any etiology, Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Diabetes, Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Asthma, Other',
#  'Hypertension, Chronic renal, Liver disease, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Dementia any etiology, Stroke, Other',
#  'Hypertension, Chronic renal, History of cancer now in remission, Diabetes, Dementia any etiology, Other',
#  'Hypertension, Diabetes, Other',
#  'Hypertension, Chronic renal, Cancer active only, Diabetes, Other',
#  'Hypertension, History of cancer now in remission, Diabetes, Stroke, Other',
#  'Chronic pulmonary (lung) disease, Dementia any etiology, Other',
#  'Obesity, Diabetes, Other',
#  'Hypertension, Obesity, Diabetes, Stroke, Other',
#  'Obesity, Other',
#  'Hypertension, Chronic renal, Stroke, Other',
#  'Diabetes, Other',
#  'Hypertension, Cancer active only, Diabetes, Other',
#  'Chronic pulmonary (lung) disease, Diabetes, Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Asthma, Obesity, Diabetes, Dementia any etiology, Other',
#  'History of cancer now in remission, Other',
#  'Chronic cardiac disease (not hypertension), Asthma, Obesity, Other',
#  'Hypertension, Cancer active only, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic renal, Diabetes, Stroke, Other',
#  'Hypertension, Dementia any etiology, Other',
#  'Chronic cardiac disease (not hypertension), Cancer active only, Dementia any etiology, Other',
#  'Chronic cardiac disease (not hypertension), Asthma, Dementia any etiology, Stroke, Other',
#  'Hypertension, Diabetes, Rheumatologic disorder, Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Cancer active only, Diabetes, Other',
#  'Chronic renal, Diabetes, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Dementia any etiology, Other',
#  'Hypertension, Diabetes, Dementia any etiology, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Dementia any etiology',
#  'Hypertension, Diabetes, Stroke, Other',
#  'Hypertension, Cancer active only, Diabetes, Stroke, Other',
#  'Asthma, Diabetes, Other',
#  'Hypertension, Asthma, Chronic renal, Cancer active only, Diabetes, Other',
#  'Chronic cardiac disease (not hypertension), Chronic renal, Diabetes, Other',
#  'Hypertension, Cancer active only, Diabetes, Hematological, Other',
#  'Cancer active only',
#  'Chronic cardiac disease (not hypertension), Hypertension, Asthma, Chronic renal, Diabetes, Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Asthma, Diabetes, Other',
#  'Asthma',
#  'Chronic cardiac disease (not hypertension), Hypertension, Diabetes, Dementia any etiology, Other',
#  'Hypertension, History of cancer now in remission, Other',
#  'Chronic pulmonary (lung) disease, Diabetes, Dementia any etiology, Other',
#  'Chronic pulmonary (lung) disease, Asthma, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic renal, Diabetes, Dementia any etiology, Stroke, Other',
#  'Hypertension, Asthma, Other',
#  'Cancer active only, Diabetes, Stroke, Other',
#  'Stroke, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Kidney disease, Diabetes, Rheumatologic disorder, Other',
#  'Chronic cardiac disease (not hypertension), Diabetes, Other',
#  'Diabetes',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic renal, Kidney disease, Diabetes, Other',
#  'Chronic cardiac disease (not hypertension)',
#  'Chronic cardiac disease (not hypertension), Hypertension, Kidney disease, Dementia any etiology, Other',
#  'Hypertension, History of cancer now in remission, Diabetes, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Diabetes, Stroke, Other',
#  'Other',
#  'Hypertension, Chronic pulmonary (lung) disease, Other',
#  'Hypertension, Asthma, Dementia any etiology, Other',
#  'Pregnancy, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic renal, Other',
#  'Chronic neurological disorder, Diabetes, Other',
#  'Hypertension, History of cancer now in remission, Obesity, Diabetes, Other',
#  'Hypertension, Asthma, Obesity, Other',
#  'Hypertension, Hematological, Other',
#  'Hypertension, Diabetes',
#  'Asthma, Obesity, Other',
#  'Dementia any etiology, Other',
#  'Chronic cardiac disease (not hypertension), Hypertension, Chronic pulmonary (lung) disease, Dementia any etiology, Other',
#  'Kidney disease, Obesity, Other']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     508 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       508 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  aptt_aptr                         288 non-null    object
#  32  pt                                315 non-null    float64
#  33  alt                               403 non-null    float64
#  34  ast                               403 non-null    float64
#  35  serum_creatinine                  506 non-null    float64
#  36  sodium                            506 non-null    float64
#  37  potassium                         506 non-null    float64
#  38  total_serum_bilirubin             403 non-null    float64
#  39  lactate                           362 non-null    float64
#  40  inr                               315 non-null    float64
#  41  d_dimer                           252 non-null    object
#  42  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(11)
# memory usage: 170.8+ KB

# %% [markdown]
# Notice above that the comorbidities column has 50 null values, but pandas is not recognizing them as such. Going to make a function to fix that.

# %%
def emptyToNull(x):
    if x=="":
        return None
    else:
        return x

# %%
df['comorbidities']=list(map(lambda x: emptyToNull(x),df['comorbidities']))

# %%
df.comorbidities.groupby(df.comorbidities).count()
# Out:
# comorbidities
# Asthma                                           5
# Asthma, Diabetes, Other                          1
# Asthma, Obesity, Other                           1
# Asthma, Other                                   11
# Cancer active only                               1
#                                                 ..
# Pregnancy                                        2
# Pregnancy, Other                                 2
# Rheumatologic disorder, Hematological, Other     1
# Rheumatologic disorder, Other                    1
# Stroke, Other                                    2
# Name: comorbidities, Length: 136, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     458 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       508 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  aptt_aptr                         288 non-null    object
#  32  pt                                315 non-null    float64
#  33  alt                               403 non-null    float64
#  34  ast                               403 non-null    float64
#  35  serum_creatinine                  506 non-null    float64
#  36  sodium                            506 non-null    float64
#  37  potassium                         506 non-null    float64
#  38  total_serum_bilirubin             403 non-null    float64
#  39  lactate                           362 non-null    float64
#  40  inr                               315 non-null    float64
#  41  d_dimer                           252 non-null    object
#  42  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(11)
# memory usage: 170.8+ KB

# %% [markdown]
# Fixed it. Now I'm going to check that if the comorbidity value of an observation is null, then the comorbidities_other value is also null for that observation.

# %%
df
# Out:
#             reason_for_admission  age     sex  height  weight  \
# 0                          Fever   74    Male     NaN     NaN
# 1                      Pneumonia   61  Female   154.9    73.6
# 2                      Pneumonia   58  Female     NaN     NaN
# 3              Probable COVID-19   94    Male   182.8    66.2
# 4    Febrile respiratory illness   91    Male     NaN     NaN
# ..                           ...  ...     ...     ...     ...
# 503          Shortness of breath   74  Female     NaN    55.0
# 504                     COVID-19   81    Male   158.0    65.0
# 505                     COVID-19   74    Male     NaN    81.7
# 506                     COVID-19   48  Female   180.0    95.3
# 507                     COVID-19   73    Male     NaN     NaN
#
#                                          comorbidities  \
# 0                        Hypertension, Diabetes, Other
# 1                                  Hypertension, Other
# 2                                         Hypertension
# 3                                  Hypertension, Other
# 4    Chronic cardiac disease (not hypertension), Hy...
# ..                                                 ...
# 503                                              Other
# 504       Hypertension, Chronic renal, Diabetes, Other
# 505                                Hypertension, Other
# 506                                               None
# 507                                               None
#
#                                    comorbidities_other  \
# 0    GERD (gastroesophageal reflux disease), Dement...
# 1    Closed fracture of fifth metatarsal bone, Dive...
# 2                                                  NaN
# 3    Parkinson's Disease, Back pain, Benign Prostat...
# 4    TAVI, Atrial fibrillation, Gastric Reflux, Pac...
# ..                                                 ...
# 503  Arthritis, High cholesterol, Hypothyroidism, V...
# 504  GERD (gastroesophageal reflux disease), High c...
# 505  Dermatitis, Hyponatremia, Irritable bowel synd...
# 506                                                NaN
# 507                                                NaN
#
#                                            medications smoking_history  \
# 0    "[{\"medications\":\"TYLENOL EXTRA STRENGTH\",...             NaN
# 1    "[{\"medications\":\"CANDESARTAN\",\"dosage\":...             NaN
# 2    "[{\"medications\":\"\",\"dosage\":\"\",\"freq...             NaN
# 3    "[{\"medications\":\"ACETYLSALICYLIC ACID  TAB...             NaN
# 4    "[{\"medications\":\"TRAZODONE\",\"dosage\":\"...       Ex-smoker
# ..                                                 ...             ...
# 503  "[{\"medications\":\"TYLENOL\",\"dosage\":\"32...      Non-smoker
# 504  "[{\"medications\":\"SYNTHROID\",\"dosage\":\"...             NaN
# 505  "[{\"medications\":\"XANAX\",\"dosage\":\"1\",...      Non-smoker
# 506                                               "[]"             NaN
# 507                                               "[]"             NaN
#
#      year_they_quit  ...    alt   ast  serum_creatinine  sodium  potassium  \
# 0               NaN  ...   53.0  49.0             165.0   135.0        3.9
# 1               NaN  ...   68.0  68.0              49.0   137.0        3.8
# 2               NaN  ...   52.0  76.0              71.0   135.0        3.7
# 3               NaN  ...    6.0  24.0             146.0   135.0        2.8
# 4               NaN  ...   17.0  26.0             109.0   142.0        3.8
# ..              ...  ...    ...   ...               ...     ...        ...
# 503             NaN  ...   30.0  41.0              72.0   131.0        4.1
# 504             NaN  ...  107.0  70.0             148.0   135.0        4.2
# 505             NaN  ...   16.0  54.0              77.0   134.0        3.8
# 506             NaN  ...   18.0  33.0              78.0   133.0        3.9
# 507             NaN  ...   56.0  37.0              79.0   140.0        3.8
#
#      total_serum_bilirubin  lactate  inr  d_dimer    crp
# 0                     10.0      2.3  1.1      NaN  223.0
# 1                     12.0      1.5  1.0     2354   95.6
# 2                      7.0      1.0  NaN      NaN    NaN
# 3                     10.0      4.5  NaN      NaN    NaN
# 4                     19.0      3.2  NaN      NaN    NaN
# ..                     ...      ...  ...      ...    ...
# 503                   10.0      2.3  1.1      NaN    NaN
# 504                   11.0      3.7  NaN    >4000    NaN
# 505                    9.0      NaN  1.5      NaN    NaN
# 506                   11.0      1.4  1.0      428    NaN
# 507                    7.0      NaN  1.1     1584    NaN
#
# [508 rows x 43 columns]

# %%
dfC=df.drop(['reason_for_admission', 'age', 'sex', 'height', 'weight',
        'medications',
       'smoking_history', 'year_they_quit', 'previous_er_visit_within_14_days',
       'admission_disposition', 'systolic_blood_pressure',
       'diastolic_blood_pressure', 'heart_rate', 'respiratory_rate',
       'oxygen_saturation', 'temperature', 'motor', 'verbal', 'eye',
       'intubated', 'wbc', 'rbc', 'hemoglobin', 'hematocrit', 'mcv', 'mch',
       'mchc', 'rdw', 'platelet_count', 'aptt_aptr', 'pt', 'alt', 'ast',
       'serum_creatinine', 'sodium', 'potassium', 'total_serum_bilirubin',
       'lactate', 'inr', 'd_dimer', 'crp'],axis=1)
dfC=dfC[dfC.comorbidities.isna()]

# %%
dfC
# Out:
#     comorbidities comorbidities_other
# 6            None                 NaN
# 10           None                 NaN
# 20           None                 NaN
# 21           None                 NaN
# 22           None                 NaN
# 37           None                 NaN
# 43           None                 NaN
# 53           None                 NaN
# 61           None                 NaN
# 64           None                 NaN
# 76           None                 NaN
# 78           None                 NaN
# 113          None                 NaN
# 119          None                 NaN
# 126          None                 NaN
# 127          None                 NaN
# 141          None                 NaN
# 149          None                 NaN
# 162          None                 NaN
# 177          None                 NaN
# 178          None                 NaN
# 179          None                 NaN
# 180          None                 NaN
# 191          None                 NaN
# 203          None                 NaN
# 232          None                 NaN
# 245          None                 NaN
# 252          None                 NaN
# 255          None                 NaN
# 262          None                 NaN
# 285          None                 NaN
# 303          None                 NaN
# 320          None                 NaN
# 322          None                 NaN
# 329          None                 NaN
# 336          None                 NaN
# 343          None                 NaN
# 344          None                 NaN
# 345          None                 NaN
# 360          None                 NaN
# 372          None                 NaN
# 381          None                 NaN
# 391          None                 NaN
# 405          None                 NaN
# 421          None                 NaN
# 448          None                 NaN
# 477          None                 NaN
# 487          None                 NaN
# 506          None                 NaN
# 507          None                 NaN

# %% [markdown]
# Great, time to move onn to looking at the rest of the categorical variables.

# %%
df.comorbidities_other.groupby(df.comorbidities_other).count()
# Out:
# comorbidities_other
# \tAcquired absence of uterus with remaining cervical stump, Atrioventricular block, Basal cell carcinoma, Cataract, Goiter, nontoxic, multinodular, Hx of varicose veins of lower extremity, Malignant neoplasm of breast, Osteoporosis, Rheumatic disorder of both mitral and aortic valves, Squamous cell carcinoma of skin, UTI (urinary tract infection)\t                                                                                                                            1
# \tGERD (gastroesophageal reflux disease), High cholesterol, MI (myocardial infarction) Anterior STEMI 2016 - PCI with DES to LAD                                                                                                                                                                                                                                                                                                                                                          1
# 1.\tPeripheral arterial disease, with multiple surgeries for critical limb ischemia, last in October 2020, on the right side. 2.\tPrior amputation-site infection.  He is colonized with ESBL-producing organisms.                                                                                                                                                                                                                                                                        1
# A-fib, BPH (benign prostatic hyperplasia), Choledocholithiasis, Dyslipidemia, Sleep apnea, UTI (urinary tract infection), Hip fracture\t2009                                                                                                                                                                                                                                                                                                                                              1
# AAA (abdominal aortic aneurysm), Basal cell carcinoma, Bowel perforation, BPH (benign prostatic hyperplasia), CAD (coronary artery disease), Delirium, Duodenal ulcer, Gastritis, History of thoracic aortic aneurysm repair, Hyperlipidemia, Mild cognitive impairment, NSTEMI (non-ST elevated myocardial infarction), Osteoarthritis, Osteoarthritis of both shoulders\t, Pacemaker, SBO (small bowel obstruction), Seizure, Tachy-brady syndrome, Transient complete heart block\t    1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ..
# obesity, hypogonadism, erectile dysfunction, pleural effusion as a child                                                                                                                                                                                                                                                                                                                                                                                                                  1
# osteoarthritis                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# recurrent urinary tract infections, The patient has a prior history of large right MCA stroke which left her with a significant neurologic deficiency, dyslipidemia                                                                                                                                                                                                                                                                                                                       1
# smoker, appendectomy, tonsillectomy, eye surgery                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# •\tAnal fissure, Arthritis, Disease of thyroid gland, GERD (gastroesophageal reflux disease), Follicular Lymphoma, grade 3b, completed maintenance Rituxan in 2017. No recurrence as of Jan 2020 , Thyroid cancer\t                                                                                                                                                                                                                                                                       1
# Name: comorbidities_other, Length: 359, dtype: int64

# %% [markdown]
# Cleaning this one up would be awful. Just going to leave it as is, and if we would like to reference it later to learn about a specific patient, it'll be there.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     458 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       508 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  aptt_aptr                         288 non-null    object
#  32  pt                                315 non-null    float64
#  33  alt                               403 non-null    float64
#  34  ast                               403 non-null    float64
#  35  serum_creatinine                  506 non-null    float64
#  36  sodium                            506 non-null    float64
#  37  potassium                         506 non-null    float64
#  38  total_serum_bilirubin             403 non-null    float64
#  39  lactate                           362 non-null    float64
#  40  inr                               315 non-null    float64
#  41  d_dimer                           252 non-null    object
#  42  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(11)
# memory usage: 170.8+ KB

# %%
df.medications.groupby(df.medications).count()
# Out:
# medications
# "[]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            10
# "[{\"medications\":\"ABILIFY\",\"dosage\":\"5\",\"frequency\":\"OD\"},{\"medications\":\"FESOTERODINE\",\"dosage\":\"8\",\"frequency\":\"OD\"},{\"medications\":\"CRESTOR  \",\"dosage\":\"10\",\"frequency\":\"OD\"},{\"medications\":\"CIPRALEX    \",\"dosage\":\"20\",\"frequency\":\"OD\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# "[{\"medications\":\"ACETAMINOPHEN TAB \",\"dosage\":\"1000\",\"frequency\":\"TID\"},{\"medications\":\"CLAVULIN  TAB\",\"dosage\":\"875-125\",\"frequency\":\"BID\"},{\"medications\":\"CHOLECALCIFEROL\",\"dosage\":\"1000 units\",\"frequency\":\"OD\"},{\"medications\":\"CYANOCOBALAMIN INJ \",\"dosage\":\"1\",\"frequency\":\"Monthly\"},{\"medications\":\"MOTILIUM TAB \",\"dosage\":\"10\",\"frequency\":\"TID\"},{\"medications\":\"SINEMET \",\"dosage\":\"150-50\",\"frequency\":\"QUID\"},{\"medications\":\"MAGNESIUM CITRATE CAPLET \",\"dosage\":\"150\",\"frequency\":\"OD\"},{\"medications\":\"MULTIVITAMINS\",\"dosage\":\"1 tab\",\"frequency\":\"OD\"},{\"medications\":\"SEROQUEL\",\"dosage\":\"25\",\"frequency\":\"PRN\"},{\"medications\":\"EXELON  \",\"dosage\":\"6\",\"frequency\":\"BID\"},{\"medications\":\"SENOKOT \",\"dosage\":\"17.2\",\"frequency\":\"OD\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# "[{\"medications\":\"ACETAMINOPHEN TAB \",\"dosage\":\"1000\",\"frequency\":\"TID\"},{\"medications\":\"METADOL\",\"dosage\":\"95\",\"frequency\":\"OD\"},{\"medications\":\"NAPROSYN \",\"dosage\":\"375\",\"frequency\":\"BID\"},{\"medications\":\"VENTOLIN HFA\",\"dosage\":\"1-2 PUFFS\",\"frequency\":\"QUID\"},{\"medications\":\"FLOMAX CR\",\"dosage\":\"0.4\",\"frequency\":\"OD\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# "[{\"medications\":\"ACETAMINOPHEN TAB \",\"dosage\":\"325-650\",\"frequency\":\"QUID\"},{\"medications\":\"CORDARONE\",\"dosage\":\"200\",\"frequency\":\"OD\"},{\"medications\":\"LIPITOR\",\"dosage\":\"80\",\"frequency\":\"OD\"},{\"medications\":\"BISOPROLOL\",\"dosage\":\"5\",\"frequency\":\"OD\"},{\"medications\":\"PLAVIX\",\"dosage\":\"75\",\"frequency\":\"OD\"},{\"medications\":\"JARDIANCE\",\"dosage\":\"25\",\"frequency\":\"OD\"},{\"medications\":\"EZETROL\",\"dosage\":\"10\",\"frequency\":\"OD\"},{\"medications\":\"FLOVENT HFA\",\"dosage\":\"0.250\",\"frequency\":\"BID\"},{\"medications\":\"LASIX TABS  \",\"dosage\":\"20\",\"frequency\":\"OD\"},{\"medications\":\"DIAMICRON MR\",\"dosage\":\"60\",\"frequency\":\"BID\"},{\"medications\":\"HYDRODIURIL TAB \",\"dosage\":\"12.5\",\"frequency\":\"OD\"},{\"medications\":\"LOZIDE\",\"dosage\":\"1.25\",\"frequency\":\"OD\"},{\"medications\":\"GLUCOPHAGE\",\"dosage\":\"500\",\"frequency\":\"BID\"},{\"medications\":\"NITROGLYCERIN\",\"dosage\":\"0.4\",\"frequency\":\"OD\"},{\"medications\":\"PANTOLOC\",\"dosage\":\"40\",\"frequency\":\"OD\"},{\"medications\":\"COVERSYL\",\"dosage\":\"8\",\"frequency\":\"OD\"},{\"medications\":\"PARIET, ENTERICCOATED TABLET \",\"dosage\":\"20\",\"frequency\":\"OD\"},{\"medications\":\"TYLENOL EXTRA STRENGTH\",\"dosage\":\"325-650\",\"frequency\":\"PRN\"}]"     1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ..
# "[{\"medications\":\"indapamide \",\"dosage\":\"1.25\",\"frequency\":\"OD\"},{\"medications\":\"ramipril \",\"dosage\":\"10\",\"frequency\":\"OD\"},{\"medications\":\"simvastatin \",\"dosage\":\"40\",\"frequency\":\"OD\"},{\"medications\":\"ATIVAN TAB \",\"dosage\":\".5\",\"frequency\":\"PRN\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# "[{\"medications\":\"jardiance\",\"dosage\":\"10\",\"frequency\":\"OD\"},{\"medications\":\"JENTADUETO\",\"dosage\":\"2.5-1,000\",\"frequency\":\"BID\"},{\"medications\":\"ENTRESTO\",\"dosage\":\"97-103\",\"frequency\":\"BID\"},{\"medications\":\"GLICLAZIDE\",\"dosage\":\"60\",\"frequency\":\"OD\"},{\"medications\":\"BISOPROLOL\",\"dosage\":\"5\",\"frequency\":\"OD\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# "[{\"medications\":\"prenatal vit #109-iron gluc-FA (TOTAL ONE MATERNITY) 27 mg iron-\",\"dosage\":\"1tab\",\"frequency\":\"OD\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# "[{\"medications\":\"salbutamol sulphate\",\"dosage\":\"1-2 puffs\",\"frequency\":\"PRN\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# "[{\"medications\":\"trazodone \",\"dosage\":\"50\",\"frequency\":\"OD\"},{\"medications\":\"dextromethorphan cough syrup\",\"dosage\":\"\",\"frequency\":\"Please Select an option\"},{\"medications\":\"metoprolol\",\"dosage\":\"25\",\"frequency\":\"BID\"},{\"medications\":\"Pantoloc \",\"dosage\":\"40\",\"frequency\":\"OD\"},{\"medications\":\"Crestor \",\"dosage\":\"10\",\"frequency\":\"OD\"},{\"medications\":\"Coumadin \",\"dosage\":\"7.5\",\"frequency\":\"OD\"}]"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Name: medications, Length: 431, dtype: int64

# %% [markdown]
# This one is so messy I can barely tell whats going on at all. I'm going to run it through the a modified version of cleanComorb function to make it a little bit nicer-- I think I'll add open and closed curly brackets to the badchar string, as those seem to be unneccessary. Then we'll see what else is wrong with this variable.

# %%
def cleanMed(x):
    badchar="{[}\]"
    for char in badchar:
        x=x.replace(char,"")
    x=x.replace('"',"")
    #x=x.replace(",",", ") #adding space after commas for aesthetic purposes
    return x

# %%
df['medications']=list(map(lambda x: cleanMed(x),df['medications']))

# %%
df.medications.groupby(df.medications).count()
# Out:
# medications
#                                                                                                                                                                                                                                                                                                                           10
# medications:,dosage:,frequency:OD                                                                                                                                                                                                                                                                                          3
# medications:,dosage:,frequency:Please Select an option                                                                                                                                                                                                                                                                    58
# medications:,dosage:,frequency:null                                                                                                                                                                                                                                                                                        2
# medications:ABILIFY,dosage:5,frequency:OD,medications:FESOTERODINE,dosage:8,frequency:OD,medications:CRESTOR  ,dosage:10,frequency:OD,medications:CIPRALEX    ,dosage:20,frequency:OD                                                                                                                                      1
#                                                                                                                                                                                                                                                                                                                           ..
# medications:indapamide ,dosage:1.25,frequency:OD,medications:ramipril ,dosage:10,frequency:OD,medications:simvastatin ,dosage:40,frequency:OD,medications:ATIVAN TAB ,dosage:.5,frequency:PRN                                                                                                                              1
# medications:jardiance,dosage:10,frequency:OD,medications:JENTADUETO,dosage:2.5-1,000,frequency:BID,medications:ENTRESTO,dosage:97-103,frequency:BID,medications:GLICLAZIDE,dosage:60,frequency:OD,medications:BISOPROLOL,dosage:5,frequency:OD                                                                             1
# medications:prenatal vit #109-iron gluc-FA (TOTAL ONE MATERNITY) 27 mg iron-,dosage:1tab,frequency:OD                                                                                                                                                                                                                      1
# medications:salbutamol sulphate,dosage:1-2 puffs,frequency:PRN                                                                                                                                                                                                                                                             1
# medications:trazodone ,dosage:50,frequency:OD,medications:dextromethorphan cough syrup,dosage:,frequency:Please Select an option,medications:metoprolol,dosage:25,frequency:BID,medications:Pantoloc ,dosage:40,frequency:OD,medications:Crestor ,dosage:10,frequency:OD,medications:Coumadin ,dosage:7.5,frequency:OD     1
# Name: medications, Length: 431, dtype: int64

# %% [markdown]
# Going to try to get rid of some of those nulls, but otherwise we'll leave it as is and perhaps drop it later. Going to make a temporary column named temlen to make sure I won't accidentally get rid of any legitimate values (as I'll be trying to locate entries that are null but not presented as such by looking at the string lengths.) Currently says there are no null values in medications, which is definitely not right. Then going to run it through emptyToNull. (If we do in other order, causes some issues.)

# %%
df['templen']=list(len(i) for i in df.medications)

# %%
df #column is there.
# Out:
#             reason_for_admission  age     sex  height  weight  \
# 0                          Fever   74    Male     NaN     NaN
# 1                      Pneumonia   61  Female   154.9    73.6
# 2                      Pneumonia   58  Female     NaN     NaN
# 3              Probable COVID-19   94    Male   182.8    66.2
# 4    Febrile respiratory illness   91    Male     NaN     NaN
# ..                           ...  ...     ...     ...     ...
# 503          Shortness of breath   74  Female     NaN    55.0
# 504                     COVID-19   81    Male   158.0    65.0
# 505                     COVID-19   74    Male     NaN    81.7
# 506                     COVID-19   48  Female   180.0    95.3
# 507                     COVID-19   73    Male     NaN     NaN
#
#                                          comorbidities  \
# 0                        Hypertension, Diabetes, Other
# 1                                  Hypertension, Other
# 2                                         Hypertension
# 3                                  Hypertension, Other
# 4    Chronic cardiac disease (not hypertension), Hy...
# ..                                                 ...
# 503                                              Other
# 504       Hypertension, Chronic renal, Diabetes, Other
# 505                                Hypertension, Other
# 506                                               None
# 507                                               None
#
#                                    comorbidities_other  \
# 0    GERD (gastroesophageal reflux disease), Dement...
# 1    Closed fracture of fifth metatarsal bone, Dive...
# 2                                                  NaN
# 3    Parkinson's Disease, Back pain, Benign Prostat...
# 4    TAVI, Atrial fibrillation, Gastric Reflux, Pac...
# ..                                                 ...
# 503  Arthritis, High cholesterol, Hypothyroidism, V...
# 504  GERD (gastroesophageal reflux disease), High c...
# 505  Dermatitis, Hyponatremia, Irritable bowel synd...
# 506                                                NaN
# 507                                                NaN
#
#                                            medications smoking_history  \
# 0    medications:TYLENOL EXTRA STRENGTH,dosage:325,...             NaN
# 1        medications:CANDESARTAN,dosage:8,frequency:OD             NaN
# 2                    medications:,dosage:,frequency:OD             NaN
# 3    medications:ACETYLSALICYLIC ACID  TAB,dosage:8...             NaN
# 4    medications:TRAZODONE,dosage:12.5,frequency:OD...       Ex-smoker
# ..                                                 ...             ...
# 503  medications:TYLENOL,dosage:325,frequency:TID,m...      Non-smoker
# 504  medications:SYNTHROID,dosage:75 mcg,frequency:...             NaN
# 505  medications:XANAX,dosage:1,frequency:OD,medica...      Non-smoker
# 506                                                                NaN
# 507                                                                NaN
#
#      year_they_quit  ...   ast serum_creatinine  sodium  potassium  \
# 0               NaN  ...  49.0            165.0   135.0        3.9
# 1               NaN  ...  68.0             49.0   137.0        3.8
# 2               NaN  ...  76.0             71.0   135.0        3.7
# 3               NaN  ...  24.0            146.0   135.0        2.8
# 4               NaN  ...  26.0            109.0   142.0        3.8
# ..              ...  ...   ...              ...     ...        ...
# 503             NaN  ...  41.0             72.0   131.0        4.1
# 504             NaN  ...  70.0            148.0   135.0        4.2
# 505             NaN  ...  54.0             77.0   134.0        3.8
# 506             NaN  ...  33.0             78.0   133.0        3.9
# 507             NaN  ...  37.0             79.0   140.0        3.8
#
#      total_serum_bilirubin  lactate  inr  d_dimer    crp  templen
# 0                     10.0      2.3  1.1      NaN  223.0      934
# 1                     12.0      1.5  1.0     2354   95.6       45
# 2                      7.0      1.0  NaN      NaN    NaN       33
# 3                     10.0      4.5  NaN      NaN    NaN      531
# 4                     19.0      3.2  NaN      NaN    NaN      591
# ..                     ...      ...  ...      ...    ...      ...
# 503                   10.0      2.3  1.1      NaN    NaN      353
# 504                   11.0      3.7  NaN    >4000    NaN      324
# 505                    9.0      NaN  1.5      NaN    NaN      625
# 506                   11.0      1.4  1.0      428    NaN        0
# 507                    7.0      NaN  1.1     1584    NaN        0
#
# [508 rows x 44 columns]

# %%
dfC=df.drop(['reason_for_admission', 'age', 'sex', 'height', 'weight',
       'comorbidities', 'comorbidities_other',
       'smoking_history', 'year_they_quit', 'previous_er_visit_within_14_days',
       'admission_disposition', 'systolic_blood_pressure',
       'diastolic_blood_pressure', 'heart_rate', 'respiratory_rate',
       'oxygen_saturation', 'temperature', 'motor', 'verbal', 'eye',
       'intubated', 'wbc', 'rbc', 'hemoglobin', 'hematocrit', 'mcv', 'mch',
       'mchc', 'rdw', 'platelet_count', 'aptt_aptr', 'pt', 'alt', 'ast',
       'serum_creatinine', 'sodium', 'potassium', 'total_serum_bilirubin',
       'lactate', 'inr', 'd_dimer', 'crp'],axis=1)

# %%
dfC.sort_values(by=['templen'],inplace=True)
dfC
# Out:
#                                            medications  templen
# 507                                                           0
# 345                                                           0
# 343                                                           0
# 391                                                           0
# 180                                                           0
# ..                                                 ...      ...
# 193  medications:TYLENOL EXTRA STRENGTH,dosage:650,...     1037
# 120  medications:BLEXTEN,dosage:20,frequency:Please...     1073
# 415  medications:TYLENOL EXTRA STRENGTH,dosage:1000...     1101
# 419  medications:TYLENOL ARTHRITIS PAIN,dosage:650,...     1458
# 299  medications:TYLENOL EXTRA STRENGTH,dosage:1000...     1870
#
# [508 rows x 2 columns]

# %%
dfC['medications']=list(map(lambda x: emptyToNull(x),dfC['medications']))

# %%
dfC.dropna(inplace=True)

# %%
dfC
# Out:
#                                            medications  templen
# 15                   medications:,dosage:,frequency:OD       33
# 113                  medications:,dosage:,frequency:OD       33
# 2                    medications:,dosage:,frequency:OD       33
# 10                 medications:,dosage:,frequency:null       35
# 6                  medications:,dosage:,frequency:null       35
# ..                                                 ...      ...
# 193  medications:TYLENOL EXTRA STRENGTH,dosage:650,...     1037
# 120  medications:BLEXTEN,dosage:20,frequency:Please...     1073
# 415  medications:TYLENOL EXTRA STRENGTH,dosage:1000...     1101
# 419  medications:TYLENOL ARTHRITIS PAIN,dosage:650,...     1458
# 299  medications:TYLENOL EXTRA STRENGTH,dosage:1000...     1870
#
# [498 rows x 2 columns]

# %%
dfC.head(100)
# Out:
#                                            medications  templen
# 15                   medications:,dosage:,frequency:OD       33
# 113                  medications:,dosage:,frequency:OD       33
# 2                    medications:,dosage:,frequency:OD       33
# 10                 medications:,dosage:,frequency:null       35
# 6                  medications:,dosage:,frequency:null       35
# ..                                                 ...      ...
# 53   medications:,dosage:,frequency:Please Select a...       54
# 76   medications:CLAVULIN  TAB,dosage:875-125,frequ...       54
# 64   medications:,dosage:,frequency:Please Select a...       54
# 21   medications:,dosage:,frequency:Please Select a...       54
# 20   medications:,dosage:,frequency:Please Select a...       54
#
# [100 rows x 2 columns]

# %% [markdown]
# Okay, going to do a double conditional to ensure we don't turn values that aren't null to nulls.

# %%
def medNulls(x):
    if len(x)<36:
        return None
    elif len(x)<65 and "medications:,dosage:,freq" in x: 
        return None
    else:
        return x

# %%
dfC['medications']=list(map(lambda x: medNulls(x),dfC['medications']))

# %%
dfC.head(100)
# Out:
#                                            medications  templen
# 15                                                None       33
# 113                                               None       33
# 2                                                 None       33
# 10                                                None       35
# 6                                                 None       35
# ..                                                 ...      ...
# 53                                                None       54
# 76   medications:CLAVULIN  TAB,dosage:875-125,frequ...       54
# 64                                                None       54
# 21                                                None       54
# 20                                                None       54
#
# [100 rows x 2 columns]

# %% [markdown]
# Looks good! Now to use that on the original dataframe and drop the temporary column.

# %%
df['medications']=list(map(lambda x: medNulls(x),df['medications']))

# %%
df.drop(['templen'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     458 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       435 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  aptt_aptr                         288 non-null    object
#  32  pt                                315 non-null    float64
#  33  alt                               403 non-null    float64
#  34  ast                               403 non-null    float64
#  35  serum_creatinine                  506 non-null    float64
#  36  sodium                            506 non-null    float64
#  37  potassium                         506 non-null    float64
#  38  total_serum_bilirubin             403 non-null    float64
#  39  lactate                           362 non-null    float64
#  40  inr                               315 non-null    float64
#  41  d_dimer                           252 non-null    object
#  42  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(11)
# memory usage: 170.8+ KB

# %%
df.medications.groupby(df.medications).count()
# Out:
# medications
# medications:ABILIFY,dosage:5,frequency:OD,medications:FESOTERODINE,dosage:8,frequency:OD,medications:CRESTOR  ,dosage:10,frequency:OD,medications:CIPRALEX    ,dosage:20,frequency:OD                                                                                                                                                                                                                                                                                                                                                                                                                 1
# medications:ACETAMINOPHEN ,dosage:1300,frequency:TID,medications:VOLTAREN TAB ,dosage:50,frequency:BID,medications:calcium vit D3 magnesium,dosage:1 tab,frequency:OD,medications:CHOLECALCIFEROL,dosage:1000 units,frequency:OD,medications:GABAPENTIN,dosage:300,frequency:BID,medications:melatonin magnesium citrate,dosage:10-150,frequency:OD,medications:VITAMIN B COMPLEX TAB,dosage:100,frequency:OD,medications:PANTOPRAZOLE,dosage:20,frequency:BID,medications:fish oil ,dosage:200,frequency:OD                                                                                          1
# medications:ACETAMINOPHEN TAB ,dosage:,frequency:PRN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# medications:ACETAMINOPHEN TAB ,dosage:1000,frequency:TID,medications:CLAVULIN  TAB,dosage:875-125,frequency:BID,medications:CHOLECALCIFEROL,dosage:1000 units,frequency:OD,medications:CYANOCOBALAMIN INJ ,dosage:1,frequency:Monthly,medications:MOTILIUM TAB ,dosage:10,frequency:TID,medications:SINEMET ,dosage:150-50,frequency:QUID,medications:MAGNESIUM CITRATE CAPLET ,dosage:150,frequency:OD,medications:MULTIVITAMINS,dosage:1 tab,frequency:OD,medications:SEROQUEL,dosage:25,frequency:PRN,medications:EXELON  ,dosage:6,frequency:BID,medications:SENOKOT ,dosage:17.2,frequency:OD    1
# medications:ACETAMINOPHEN TAB ,dosage:1000,frequency:TID,medications:METADOL,dosage:95,frequency:OD,medications:NAPROSYN ,dosage:375,frequency:BID,medications:VENTOLIN HFA,dosage:1-2 PUFFS,frequency:QUID,medications:FLOMAX CR,dosage:0.4,frequency:OD                                                                                                                                                                                                                                                                                                                                             1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ..
# medications:indapamide ,dosage:1.25,frequency:OD,medications:ramipril ,dosage:10,frequency:OD,medications:simvastatin ,dosage:40,frequency:OD,medications:ATIVAN TAB ,dosage:.5,frequency:PRN                                                                                                                                                                                                                                                                                                                                                                                                         1
# medications:jardiance,dosage:10,frequency:OD,medications:JENTADUETO,dosage:2.5-1,000,frequency:BID,medications:ENTRESTO,dosage:97-103,frequency:BID,medications:GLICLAZIDE,dosage:60,frequency:OD,medications:BISOPROLOL,dosage:5,frequency:OD                                                                                                                                                                                                                                                                                                                                                        1
# medications:prenatal vit #109-iron gluc-FA (TOTAL ONE MATERNITY) 27 mg iron-,dosage:1tab,frequency:OD                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# medications:salbutamol sulphate,dosage:1-2 puffs,frequency:PRN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# medications:trazodone ,dosage:50,frequency:OD,medications:dextromethorphan cough syrup,dosage:,frequency:Please Select an option,medications:metoprolol,dosage:25,frequency:BID,medications:Pantoloc ,dosage:40,frequency:OD,medications:Crestor ,dosage:10,frequency:OD,medications:Coumadin ,dosage:7.5,frequency:OD                                                                                                                                                                                                                                                                                1
# Name: medications, Length: 427, dtype: int64

# %% [markdown]
# Got rid of over 70 null values that were labeled as non-null in the medication column. Good!
# Next to deal with is "smoking_history"

# %%
df.smoking_history
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4       Ex-smoker
#           ...
# 503    Non-smoker
# 504           NaN
# 505    Non-smoker
# 506           NaN
# 507           NaN
# Name: smoking_history, Length: 508, dtype: object

# %%
df.smoking_history.groupby(df.smoking_history).count()
# Out:
# smoking_history
# Ex-smoker                      66
# Non-smoker                    218
# Smoker: < 30 pack years         1
# Smoker: pack years unknown     11
# Name: smoking_history, dtype: int64

# %% [markdown]
# There is only one value for <30 pack years smoker, and the rest of the values for smokers are Smoker: pack years unknown. I'm going to combine those two values into a single value.

# %%
def combSmoke(x):
    if type(x)==str:
        if 'years' in x:
            return 'Smoker'
        else:
            return x
    else:
        return x
df['smoking_history']=list(map(lambda x: combSmoke(x),df.smoking_history))

# %%
df.smoking_history.groupby(df.smoking_history).count()
# Out:
# smoking_history
# Ex-smoker      66
# Non-smoker    218
# Smoker         12
# Name: smoking_history, dtype: int64

# %% [markdown]
# Now to look at  "year_they_quit". From df.info, we know that it only has 43 values, which means not every Ex-smoker has an entry.

# %%
df.year_they_quit.describe()
# Out:
# count      43.000000
# mean     1999.744186
# std        15.433564
# min      1971.000000
# 25%      1990.000000
# 50%      2000.000000
# 75%      2013.500000
# max      2021.000000
# Name: year_they_quit, dtype: float64

# %%
df.year_they_quit.groupby(df.year_they_quit).count()
# Out:
# year_they_quit
# 1971.0    3
# 1975.0    1
# 1980.0    3
# 1984.0    1
# 1986.0    2
# 1990.0    3
# 1991.0    2
# 1995.0    1
# 1996.0    1
# 1998.0    3
# 2000.0    2
# 2001.0    3
# 2005.0    2
# 2006.0    1
# 2009.0    1
# 2010.0    2
# 2011.0    1
# 2016.0    2
# 2017.0    1
# 2019.0    2
# 2020.0    4
# 2021.0    2
# Name: year_they_quit, dtype: int64

# %%
df['year_they_quit'] = df['year_they_quit'].fillna(0).astype(int)
print(df.dtypes)
# Out:
# reason_for_admission                 object
# age                                   int64
# sex                                  object
# height                              float64
# weight                              float64
# comorbidities                        object
# comorbidities_other                  object
# medications                          object
# smoking_history                      object
# year_they_quit                        int64
# previous_er_visit_within_14_days     object
# admission_disposition                object
# systolic_blood_pressure               int64
# diastolic_blood_pressure              int64
# heart_rate                            int64
# respiratory_rate                      int64
# oxygen_saturation                     int64
# temperature                         float64
# motor                               float64
# verbal                              float64
# eye                                 float64
# intubated                            object
# wbc                                 float64
# rbc                                 float64
# hemoglobin                          float64
# hematocrit                          float64
# mcv                                 float64
# mch                                 float64
# mchc                                float64
# rdw                                 float64
# platelet_count                      float64
# aptt_aptr                            object
# pt                                  float64
# alt                                 float64
# ast                                 float64
# serum_creatinine                    float64
# sodium                              float64
# potassium                           float64
# total_serum_bilirubin               float64
# lactate                             float64
# inr                                 float64
# d_dimer                              object
# crp                                 float64
# dtype: object

# %%
df['year_they_quit']=list(map(lambda x: None if x==0 else x,df['year_they_quit']))

# %%
df.year_they_quit.groupby(df.year_they_quit).count()
# Out:
# year_they_quit
# 1971.0    3
# 1975.0    1
# 1980.0    3
# 1984.0    1
# 1986.0    2
# 1990.0    3
# 1991.0    2
# 1995.0    1
# 1996.0    1
# 1998.0    3
# 2000.0    2
# 2001.0    3
# 2005.0    2
# 2006.0    1
# 2009.0    1
# 2010.0    2
# 2011.0    1
# 2016.0    2
# 2017.0    1
# 2019.0    2
# 2020.0    4
# 2021.0    2
# Name: year_they_quit, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     458 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       435 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  aptt_aptr                         288 non-null    object
#  32  pt                                315 non-null    float64
#  33  alt                               403 non-null    float64
#  34  ast                               403 non-null    float64
#  35  serum_creatinine                  506 non-null    float64
#  36  sodium                            506 non-null    float64
#  37  potassium                         506 non-null    float64
#  38  total_serum_bilirubin             403 non-null    float64
#  39  lactate                           362 non-null    float64
#  40  inr                               315 non-null    float64
#  41  d_dimer                           252 non-null    object
#  42  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(11)
# memory usage: 170.8+ KB

# %% [markdown]
# Looks okay. May go back later to change it to how many years before 2021 they quit. It's a bit annoying that I can't fix the data type.

# %%
df.previous_er_visit_within_14_days.describe()
# Out:
# count     508
# unique      2
# top        No
# freq      401
# Name: previous_er_visit_within_14_days, dtype: object

# %%
df.previous_er_visit_within_14_days.groupby(df.previous_er_visit_within_14_days).count()
# Out:
# previous_er_visit_within_14_days
# No     401
# Yes    107
# Name: previous_er_visit_within_14_days, dtype: int64

# %%
df.admission_disposition.groupby(df.admission_disposition).count()
# Out:
# admission_disposition
# ICU      43
# WARD    465
# Name: admission_disposition, dtype: int64

# %%
df.intubated.groupby(df.intubated).count()
# Out:
# intubated
# No     493
# Yes     15
# Name: intubated, dtype: int64

# %% [markdown]
# Admission disposition and Intubated seem mostly useless, so I may drop them later. Previous ER Visit also may be dropped.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     458 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       435 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  aptt_aptr                         288 non-null    object
#  32  pt                                315 non-null    float64
#  33  alt                               403 non-null    float64
#  34  ast                               403 non-null    float64
#  35  serum_creatinine                  506 non-null    float64
#  36  sodium                            506 non-null    float64
#  37  potassium                         506 non-null    float64
#  38  total_serum_bilirubin             403 non-null    float64
#  39  lactate                           362 non-null    float64
#  40  inr                               315 non-null    float64
#  41  d_dimer                           252 non-null    object
#  42  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(11)
# memory usage: 170.8+ KB

# %%
df.aptt_aptr
# Out:
# 0       44
# 1       28
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 503     28
# 504     31
# 505     30
# 506     31
# 507     28
# Name: aptt_aptr, Length: 508, dtype: object

# %% [markdown]
# I'm unsure what this column is, or why the values are objects instead of integers. I'll go ahead and drop it.

# %%
df.drop(['aptt_aptr'],inplace=True,axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 42 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   reason_for_admission              508 non-null    object
#  1   age                               508 non-null    int64
#  2   sex                               508 non-null    object
#  3   height                            272 non-null    float64
#  4   weight                            358 non-null    float64
#  5   comorbidities                     458 non-null    object
#  6   comorbidities_other               404 non-null    object
#  7   medications                       435 non-null    object
#  8   smoking_history                   296 non-null    object
#  9   year_they_quit                    43 non-null     float64
#  10  previous_er_visit_within_14_days  508 non-null    object
#  11  admission_disposition             508 non-null    object
#  12  systolic_blood_pressure           508 non-null    int64
#  13  diastolic_blood_pressure          508 non-null    int64
#  14  heart_rate                        508 non-null    int64
#  15  respiratory_rate                  508 non-null    int64
#  16  oxygen_saturation                 508 non-null    int64
#  17  temperature                       508 non-null    float64
#  18  motor                             506 non-null    float64
#  19  verbal                            506 non-null    float64
#  20  eye                               506 non-null    float64
#  21  intubated                         508 non-null    object
#  22  wbc                               506 non-null    float64
#  23  rbc                               506 non-null    float64
#  24  hemoglobin                        506 non-null    float64
#  25  hematocrit                        506 non-null    float64
#  26  mcv                               506 non-null    float64
#  27  mch                               506 non-null    float64
#  28  mchc                              506 non-null    float64
#  29  rdw                               506 non-null    float64
#  30  platelet_count                    506 non-null    float64
#  31  pt                                315 non-null    float64
#  32  alt                               403 non-null    float64
#  33  ast                               403 non-null    float64
#  34  serum_creatinine                  506 non-null    float64
#  35  sodium                            506 non-null    float64
#  36  potassium                         506 non-null    float64
#  37  total_serum_bilirubin             403 non-null    float64
#  38  lactate                           362 non-null    float64
#  39  inr                               315 non-null    float64
#  40  d_dimer                           252 non-null    object
#  41  crp                               142 non-null    float64
# dtypes: float64(26), int64(6), object(10)
# memory usage: 166.8+ KB

# %%
df.columns
# Out:
# Index(['reason_for_admission', 'age', 'sex', 'height', 'weight',
#        'comorbidities', 'comorbidities_other', 'medications',
#        'smoking_history', 'year_they_quit', 'previous_er_visit_within_14_days',
#        'admission_disposition', 'systolic_blood_pressure',
#        'diastolic_blood_pressure', 'heart_rate', 'respiratory_rate',
#        'oxygen_saturation', 'temperature', 'motor', 'verbal', 'eye',
#        'intubated', 'wbc', 'rbc', 'hemoglobin', 'hematocrit', 'mcv', 'mch',
#        'mchc', 'rdw', 'platelet_count', 'pt', 'alt', 'ast', 'serum_creatinine',
#        'sodium', 'potassium', 'total_serum_bilirubin', 'lactate', 'inr',
#        'd_dimer', 'crp'],
#       dtype='object')

# %%
newNames=['reason', 'age', 'sex', 'height', 'weight',
       'comorb', 'comorbid_other', 'meds',
       'smoke_hist', 'year_quit', 'er_2_weeks',
       'admission_disposition', 'systolic_bp',
       'diastolic_bp', 'heart_rate', 'respiratory_rate',
       'oxygen_sat', 'temp', 'motor', 'verbal', 'eye',
       'intubated', 'wbc', 'rbc', 'hemoglobin', 'hematocrit', 'mcv', 'mch',
       'mchc', 'rdw', 'platelet_count', 'pt', 'alt', 'ast', 'serum_creatinine',
       'sodium', 'potassium', 'total_serum_bilirubin', 'lactate', 'inr',
       'd_dimer', 'crp']

# %%
df.columns=newNames

# %%
df
# Out:
#                           reason  age     sex  height  weight  \
# 0                          Fever   74    Male     NaN     NaN
# 1                      Pneumonia   61  Female   154.9    73.6
# 2                      Pneumonia   58  Female     NaN     NaN
# 3              Probable COVID-19   94    Male   182.8    66.2
# 4    Febrile respiratory illness   91    Male     NaN     NaN
# ..                           ...  ...     ...     ...     ...
# 503          Shortness of breath   74  Female     NaN    55.0
# 504                     COVID-19   81    Male   158.0    65.0
# 505                     COVID-19   74    Male     NaN    81.7
# 506                     COVID-19   48  Female   180.0    95.3
# 507                     COVID-19   73    Male     NaN     NaN
#
#                                                 comorb  \
# 0                        Hypertension, Diabetes, Other
# 1                                  Hypertension, Other
# 2                                         Hypertension
# 3                                  Hypertension, Other
# 4    Chronic cardiac disease (not hypertension), Hy...
# ..                                                 ...
# 503                                              Other
# 504       Hypertension, Chronic renal, Diabetes, Other
# 505                                Hypertension, Other
# 506                                               None
# 507                                               None
#
#                                         comorbid_other  \
# 0    GERD (gastroesophageal reflux disease), Dement...
# 1    Closed fracture of fifth metatarsal bone, Dive...
# 2                                                  NaN
# 3    Parkinson's Disease, Back pain, Benign Prostat...
# 4    TAVI, Atrial fibrillation, Gastric Reflux, Pac...
# ..                                                 ...
# 503  Arthritis, High cholesterol, Hypothyroidism, V...
# 504  GERD (gastroesophageal reflux disease), High c...
# 505  Dermatitis, Hyponatremia, Irritable bowel synd...
# 506                                                NaN
# 507                                                NaN
#
#                                                   meds  smoke_hist  year_quit  \
# 0    medications:TYLENOL EXTRA STRENGTH,dosage:325,...         NaN        NaN
# 1        medications:CANDESARTAN,dosage:8,frequency:OD         NaN        NaN
# 2                                                 None         NaN        NaN
# 3    medications:ACETYLSALICYLIC ACID  TAB,dosage:8...         NaN        NaN
# 4    medications:TRAZODONE,dosage:12.5,frequency:OD...   Ex-smoker        NaN
# ..                                                 ...         ...        ...
# 503  medications:TYLENOL,dosage:325,frequency:TID,m...  Non-smoker        NaN
# 504  medications:SYNTHROID,dosage:75 mcg,frequency:...         NaN        NaN
# 505  medications:XANAX,dosage:1,frequency:OD,medica...  Non-smoker        NaN
# 506                                               None         NaN        NaN
# 507                                               None         NaN        NaN
#
#      ...    alt   ast  serum_creatinine  sodium  potassium  \
# 0    ...   53.0  49.0             165.0   135.0        3.9
# 1    ...   68.0  68.0              49.0   137.0        3.8
# 2    ...   52.0  76.0              71.0   135.0        3.7
# 3    ...    6.0  24.0             146.0   135.0        2.8
# 4    ...   17.0  26.0             109.0   142.0        3.8
# ..   ...    ...   ...               ...     ...        ...
# 503  ...   30.0  41.0              72.0   131.0        4.1
# 504  ...  107.0  70.0             148.0   135.0        4.2
# 505  ...   16.0  54.0              77.0   134.0        3.8
# 506  ...   18.0  33.0              78.0   133.0        3.9
# 507  ...   56.0  37.0              79.0   140.0        3.8
#
#      total_serum_bilirubin  lactate  inr  d_dimer    crp
# 0                     10.0      2.3  1.1      NaN  223.0
# 1                     12.0      1.5  1.0     2354   95.6
# 2                      7.0      1.0  NaN      NaN    NaN
# 3                     10.0      4.5  NaN      NaN    NaN
# 4                     19.0      3.2  NaN      NaN    NaN
# ..                     ...      ...  ...      ...    ...
# 503                   10.0      2.3  1.1      NaN    NaN
# 504                   11.0      3.7  NaN    >4000    NaN
# 505                    9.0      NaN  1.5      NaN    NaN
# 506                   11.0      1.4  1.0      428    NaN
# 507                    7.0      NaN  1.1     1584    NaN
#
# [508 rows x 42 columns]

# %% [markdown]
# ### Work for Part II and III.

# %%
dfj=df.drop([
       'comorbid_other',
       'smoke_hist', 'year_quit',
        'height','weight',
       'temp', 'motor', 'verbal', 'eye',
       'intubated', 'wbc', 'rbc', 'hemoglobin', 'hematocrit', 'mcv', 'mch',
       'mchc', 'rdw', 'platelet_count', 'pt', 'alt', 'ast', 'serum_creatinine',
       'sodium', 'potassium', 'total_serum_bilirubin', 'lactate', 'inr',
       'd_dimer', 'crp'],axis=1)

# %%
dfj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   reason                 508 non-null    object
#  1   age                    508 non-null    int64
#  2   sex                    508 non-null    object
#  3   comorb                 458 non-null    object
#  4   meds                   435 non-null    object
#  5   er_2_weeks             508 non-null    object
#  6   admission_disposition  508 non-null    object
#  7   systolic_bp            508 non-null    int64
#  8   diastolic_bp           508 non-null    int64
#  9   heart_rate             508 non-null    int64
#  10  respiratory_rate       508 non-null    int64
#  11  oxygen_sat             508 non-null    int64
# dtypes: int64(6), object(6)
# memory usage: 47.8+ KB

# %% [markdown]
# dfj.drop(['id','ethnicity_other', 'received_covid_vaccine',
#           'covid_vaccine','temperature', 'motor',
#        'verbal', 'eye', 'intubated', 'wbc', 'rbc',
#           'hemoglobin', 'hematocrit',
#        'mcv', 'mch', 'mchc', 'rdw', 'platelet_count',
#           'aptt_aptr', 'pt', 'alt',
#        'ast', 'serum_creatinine', 'sodium', 'potassium',
#        'total_serum_bilirubin', 'lactate','pao2', 'pao2_fio2', 'ph',
#        'high_senstivity_cardiac_troponin', 'esr','ferritin','crp','hs_crp',
#         'height','weight','smoking_history',
#         'comorbidities_other','year_they_quit','inr','d_dimer'],axis=1,inplace=True)
#         For future reference

# %%
dfj.shape
# Out:
# (508, 12)

# %% [markdown]
# ##### Cleaning the data before analyzing

# %%
dfj.columns
# Out:
# Index(['reason', 'age', 'sex', 'comorb', 'meds', 'er_2_weeks',
#        'admission_disposition', 'systolic_bp', 'diastolic_bp', 'heart_rate',
#        'respiratory_rate', 'oxygen_sat'],
#       dtype='object')

# %%
dfj.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   reason                 508 non-null    object
#  1   age                    508 non-null    int64
#  2   sex                    508 non-null    object
#  3   comorb                 458 non-null    object
#  4   meds                   435 non-null    object
#  5   er_2_weeks             508 non-null    object
#  6   admission_disposition  508 non-null    object
#  7   systolic_bp            508 non-null    int64
#  8   diastolic_bp           508 non-null    int64
#  9   heart_rate             508 non-null    int64
#  10  respiratory_rate       508 non-null    int64
#  11  oxygen_sat             508 non-null    int64
# dtypes: int64(6), object(6)
# memory usage: 47.8+ KB

# %%
dfj.describe()
# Out:
#               age  systolic_bp  diastolic_bp  heart_rate  respiratory_rate  \
# count  508.000000   508.000000    508.000000  508.000000        508.000000
# mean    66.027559   129.362205     75.566929   97.397638         24.901575
# std     16.394160    22.051194     12.851352   17.513347          7.170656
# min     19.000000    85.000000     22.000000   41.000000         12.000000
# 25%     55.750000   115.000000     68.000000   86.000000         20.000000
# 50%     66.000000   127.000000     75.000000   98.000000         24.000000
# 75%     78.000000   143.000000     83.000000  109.000000         28.000000
# max    100.000000   227.000000    145.000000  161.000000         59.000000
#
#        oxygen_sat
# count  508.000000
# mean    93.100394
# std      6.102006
# min     47.000000
# 25%     92.000000
# 50%     94.000000
# 75%     96.000000
# max    100.000000

# %% [markdown]
# #### Sorting

# %%
dfj.sort_values(by="age", ascending=False).head()
# Out:
#                   reason  age     sex  \
# 373            Pneumonia  100    Male
# 347  Respiratory failure   99    Male
# 413            Hypoxemia   98    Male
# 390            Pneumonia   98  Female
# 475            Hypoxemia   97  Female
#
#                                                 comorb  \
# 373  Chronic cardiac disease (not hypertension), Hy...
# 347  Chronic cardiac disease (not hypertension), Hy...
# 413                                              Other
# 390                 Hypertension, Chronic renal, Other
# 475  Hypertension, Asthma, Dementia any etiology, O...
#
#                                                   meds er_2_weeks  \
# 373  medications:ACETAMINOPHEN TAB ,dosage:325,freq...         No
# 347  medications:MEMANTINE,dosage:,frequency:Please...         No
# 413  medications:TYLENOL EXTRA STRENGTH,dosage:500,...         No
# 390  medications:amLODIPine (NORVASC),dosage:10,fre...         No
# 475  medications:TYLENOL EXTRA STRENGTH,dosage:650,...         No
#
#     admission_disposition  systolic_bp  diastolic_bp  heart_rate  \
# 373                  WARD           91            52          67
# 347                  WARD          136            77          95
# 413                  WARD          154            79          82
# 390                  WARD          138            63          82
# 475                  WARD          145            76         112
#
#      respiratory_rate  oxygen_sat
# 373                32          96
# 347                32          83
# 413                18          92
# 390                20          94
# 475                32          93

# %%
dfj.sort_values(by=["reason", "age"], ascending=[True, False]).head()
# Out:
#                                   reason  age     sex  \
# 371  Acute respiratory distress syndrome   78    Male
# 362  Acute respiratory distress syndrome   42    Male
# 165                             COVID-19   97  Female
# 115                             COVID-19   95    Male
# 293                             COVID-19   95    Male
#
#                                                 comorb  \
# 371       Hypertension, Chronic renal, Diabetes, Other
# 362                                            Obesity
# 165  Chronic cardiac disease (not hypertension), Hy...
# 115        Cancer active only, Diabetes, Stroke, Other
# 293                                Hypertension, Other
#
#                                                   meds er_2_weeks  \
# 371  medications:NORVASC,dosage:10,frequency:OD,med...         No
# 362                                               None        Yes
# 165  medications:NORVASC,dosage:10,frequency:OD,med...         No
# 115  medications:TYLENOL EXTRA STRENGTH,dosage:500,...         No
# 293  medications:TYLENOL EXTRA STRENGTH,dosage:650,...        Yes
#
#     admission_disposition  systolic_bp  diastolic_bp  heart_rate  \
# 371                   ICU          156            67          90
# 362                  WARD          120            86         112
# 165                  WARD           89            60          88
# 115                  WARD          169            80          74
# 293                  WARD          146            89         110
#
#      respiratory_rate  oxygen_sat
# 371                40          86
# 362                26          94
# 165                36          98
# 115                22          94
# 293                28          92

# %% [markdown]
# #### Indexing and retrieving data

# %%
dfj["age"].mean()
# Out:
# 66.0275590551181

# %% [markdown]
# #### Checking the amount inpatients above the age of 32 as Afib is neccessarily checked with older patients but when found with younger patients it's usually due to other heart conditions. Which would be nice to keep in mind when checking through respiratory illnesses tied with Covid or pneumonia

# %%
dfj[dfj["age"] <=32 ].count()
# Out:
# reason                   14
# age                      14
# sex                      14
# comorb                   10
# meds                     11
# er_2_weeks               14
# admission_disposition    14
# systolic_bp              14
# diastolic_bp             14
# heart_rate               14
# respiratory_rate         14
# oxygen_sat               14
# dtype: int64

# %%
np.max(dfj["heart_rate"])
# Out:
# 161

# %%
dfj['heart_rate'].argmax()
# Out:
# 504

# %% [markdown]
# ##### So now we know which row has the max heart rate within the dataset of patient information we can check the other information for that row

# %%
Patient_0 = dfj.iloc[504]
Patient_0
# Out:
# reason                                                            COVID-19
# age                                                                     81
# sex                                                                   Male
# comorb                        Hypertension, Chronic renal, Diabetes, Other
# meds                     medications:SYNTHROID,dosage:75 mcg,frequency:...
# er_2_weeks                                                             Yes
# admission_disposition                                                 WARD
# systolic_bp                                                            161
# diastolic_bp                                                            81
# heart_rate                                                             161
# respiratory_rate                                                        55
# oxygen_sat                                                              84
# Name: 504, dtype: object

# %%
dfj['heart_rate'].argmin()
# Out:
# 444

# %%
Patient_1 = dfj.iloc[444]
Patient_1
# Out:
# reason                                                           Pneumonia
# age                                                                     79
# sex                                                                   Male
# comorb                   Chronic cardiac disease (not hypertension), Hy...
# meds                     medications:ELIQUIS,dosage:5,frequency:BID,med...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                             87
# diastolic_bp                                                            66
# heart_rate                                                              41
# respiratory_rate                                                        18
# oxygen_sat                                                             100
# Name: 444, dtype: object

# %%
Patient_2 = dfj.iloc[305]
Patient_2
# Out:
# reason                                                           Pneumonia
# age                                                                     47
# sex                                                                   Male
# comorb                                       Hypertension, Diabetes, Other
# meds                     medications:NORVASC,dosage:10,frequency:OD,med...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                            112
# diastolic_bp                                                            81
# heart_rate                                                             117
# respiratory_rate                                                        20
# oxygen_sat                                                              96
# Name: 305, dtype: object

# %%
Patient_3 = dfj.iloc[112]
Patient_3
# Out:
# reason                                                            COVID-19
# age                                                                     74
# sex                                                                 Female
# comorb                                                       Asthma, Other
# meds                     medications:PANTOPRAZOLE,dosage:40,frequency:O...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                            113
# diastolic_bp                                                            71
# heart_rate                                                              84
# respiratory_rate                                                        20
# oxygen_sat                                                              92
# Name: 112, dtype: object

# %%
Patient_4 = dfj.iloc[53]
Patient_4
# Out:
# reason                   Pneumonia
# age                             34
# sex                           Male
# comorb                        None
# meds                          None
# er_2_weeks                      No
# admission_disposition         WARD
# systolic_bp                    125
# diastolic_bp                    70
# heart_rate                     102
# respiratory_rate                18
# oxygen_sat                      96
# Name: 53, dtype: object

# %%
Patient_5 = dfj.iloc[6]
Patient_5
# Out:
# reason                   COVID-19
# age                            50
# sex                          Male
# comorb                       None
# meds                         None
# er_2_weeks                     No
# admission_disposition        WARD
# systolic_bp                   149
# diastolic_bp                  100
# heart_rate                    130
# respiratory_rate               20
# oxygen_sat                     94
# Name: 6, dtype: object

# %%
Patient_6 = dfj.iloc[110]
Patient_6
# Out:
# reason                                                            COVID-19
# age                                                                     68
# sex                                                                   Male
# comorb                                                 Hypertension, Other
# meds                     medications:PENNSAID,dosage:4 drops,frequency:...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                            127
# diastolic_bp                                                            90
# heart_rate                                                              89
# respiratory_rate                                                        26
# oxygen_sat                                                              94
# Name: 110, dtype: object

# %%
Patient_7 = dfj.iloc[201]
Patient_7
# Out:
# reason                                                          COVID-19
# age                                                                   65
# sex                                                                 Male
# comorb                                     Hypertension, Diabetes, Other
# meds                     medications:ROSUVASTATIN,dosage:20,frequency:OD
# er_2_weeks                                                            No
# admission_disposition                                               WARD
# systolic_bp                                                          126
# diastolic_bp                                                          80
# heart_rate                                                           108
# respiratory_rate                                                      24
# oxygen_sat                                                            94
# Name: 201, dtype: object

# %%
Patient_8 = dfj.iloc[93]
Patient_8
# Out:
# reason                                                           Pneumonia
# age                                                                     76
# sex                                                                   Male
# comorb                                                 Hypertension, Other
# meds                     medications:TYLENOL EXTRA STRENGTH,dosage:500,...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                            115
# diastolic_bp                                                            57
# heart_rate                                                             112
# respiratory_rate                                                        28
# oxygen_sat                                                              96
# Name: 93, dtype: object

# %%
Patient_9 = dfj.iloc[84]
Patient_9
# Out:
# reason                                                            COVID-19
# age                                                                     62
# sex                                                                   Male
# comorb                   Chronic cardiac disease (not hypertension), Hy...
# meds                     medications:ACETYLSALICYLIC ACID  TAB,dosage:8...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                            108
# diastolic_bp                                                            66
# heart_rate                                                              72
# respiratory_rate                                                        22
# oxygen_sat                                                              92
# Name: 84, dtype: object

# %%
Patient_10 = dfj.iloc[150]
Patient_10
# Out:
# reason                        COVID-19
# age                                 39
# sex                               Male
# comorb                   Asthma, Other
# meds                              None
# er_2_weeks                          No
# admission_disposition             WARD
# systolic_bp                        125
# diastolic_bp                        82
# heart_rate                         102
# respiratory_rate                    28
# oxygen_sat                          97
# Name: 150, dtype: object

# %%
Patient_11 = dfj.iloc[300]
Patient_11
# Out:
# reason                                                         Pneumonia
# age                                                                   40
# sex                                                               Female
# comorb                                                             Other
# meds                     medications:ESCITALOPRAM,dosage:10,frequency:OD
# er_2_weeks                                                            No
# admission_disposition                                               WARD
# systolic_bp                                                           99
# diastolic_bp                                                          68
# heart_rate                                                           109
# respiratory_rate                                                      38
# oxygen_sat                                                            90
# Name: 300, dtype: object

# %%
Patient_12 = dfj.iloc[26]
Patient_12
# Out:
# reason                   COVID-19
# age                            33
# sex                          Male
# comorb                      Other
# meds                         None
# er_2_weeks                     No
# admission_disposition        WARD
# systolic_bp                   126
# diastolic_bp                   83
# heart_rate                    101
# respiratory_rate               22
# oxygen_sat                     96
# Name: 26, dtype: object

# %%
Patient_13 = dfj.iloc[14]
Patient_13
# Out:
# reason                                                            COVID-19
# age                                                                     58
# sex                                                                 Female
# comorb                   Hypertension, Chronic pulmonary (lung) disease...
# meds                     medications:ACETAMINOPHEN TAB ,dosage:650,freq...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                            142
# diastolic_bp                                                           101
# heart_rate                                                             102
# respiratory_rate                                                        24
# oxygen_sat                                                              96
# Name: 14, dtype: object

# %%
Patient_14 = dfj.iloc[299]
Patient_14
# Out:
# reason                                                               Fever
# age                                                                     76
# sex                                                                 Female
# comorb                   Chronic cardiac disease (not hypertension), Hy...
# meds                     medications:TYLENOL EXTRA STRENGTH,dosage:1000...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                            121
# diastolic_bp                                                            79
# heart_rate                                                             104
# respiratory_rate                                                        21
# oxygen_sat                                                              95
# Name: 299, dtype: object

# %%
Patient_15 = dfj.iloc[71]
Patient_15
# Out:
# reason                                                            COVID-19
# age                                                                     63
# sex                                                                 Female
# comorb                                 Hypertension, Kidney disease, Other
# meds                     medications:ELIQUIS,dosage:5,frequency:BID,med...
# er_2_weeks                                                              No
# admission_disposition                                                 WARD
# systolic_bp                                                            137
# diastolic_bp                                                            59
# heart_rate                                                              97
# respiratory_rate                                                        28
# oxygen_sat                                                              96
# Name: 71, dtype: object

# %%
Patient_16 = dfj.iloc[55]
Patient_16
# Out:
# reason                                                               Cough
# age                                                                     77
# sex                                                                 Female
# comorb                                                 Hypertension, Other
# meds                     medications:RABEPRAZOLE,dosage:20,frequency:OD...
# er_2_weeks                                                             Yes
# admission_disposition                                                 WARD
# systolic_bp                                                            175
# diastolic_bp                                                            91
# heart_rate                                                              71
# respiratory_rate                                                        18
# oxygen_sat                                                              97
# Name: 55, dtype: object

# %%
Patient_17 = dfj.iloc[421]
Patient_17
# Out:
# reason                                     Pneumonia due to COVID-19 virus
# age                                                                     36
# sex                                                                 Female
# comorb                                                                None
# meds                     medications:PRENATAL VITAMIN AND MINERAL SUPPL...
# er_2_weeks                                                             Yes
# admission_disposition                                                 WARD
# systolic_bp                                                            127
# diastolic_bp                                                            76
# heart_rate                                                             128
# respiratory_rate                                                        42
# oxygen_sat                                                              95
# Name: 421, dtype: object

# %%
Patient_18 = dfj.iloc[507]
Patient_18
# Out:
# reason                   COVID-19
# age                            73
# sex                          Male
# comorb                       None
# meds                         None
# er_2_weeks                    Yes
# admission_disposition        WARD
# systolic_bp                   121
# diastolic_bp                   76
# heart_rate                     86
# respiratory_rate               24
# oxygen_sat                     98
# Name: 507, dtype: object

# %%
Patient_19 = dfj.iloc[476]
Patient_19
# Out:
# reason                                                 Shortness of breath
# age                                                                     57
# sex                                                                 Female
# comorb                                       Hypertension, Diabetes, Other
# meds                     medications:LANTUS,dosage:70 units,frequency:O...
# er_2_weeks                                                              No
# admission_disposition                                                  ICU
# systolic_bp                                                            122
# diastolic_bp                                                            53
# heart_rate                                                              47
# respiratory_rate                                                        36
# oxygen_sat                                                              47
# Name: 476, dtype: object

# %%
Patient_20 = dfj.iloc[500]
Patient_20
# Out:
# reason                                                           Pneumonia
# age                                                                     57
# sex                                                                   Male
# comorb                   Hypertension, Chronic pulmonary (lung) disease...
# meds                     medications:COGENTIN TAB ,dosage:1,frequency:B...
# er_2_weeks                                                             Yes
# admission_disposition                                                 WARD
# systolic_bp                                                            142
# diastolic_bp                                                            78
# heart_rate                                                              90
# respiratory_rate                                                        24
# oxygen_sat                                                              95
# Name: 500, dtype: object

# %%
Patients = Patient_0,Patient_1,Patient_2,Patient_3,Patient_4,Patient_5,Patient_6,Patient_7,Patient_8,Patient_9,Patient_10,Patient_11,Patient_12,Patient_13,Patient_14,Patient_15,Patient_16,Patient_17,Patient_18,Patient_19,Patient_20

# %%
Patient = pd.DataFrame(Patients)

# %%
Patient.describe()
# Out:
#              age  systolic_bp  diastolic_bp  heart_rate  respiratory_rate  \
# count  21.000000    21.000000     21.000000   21.000000         21.000000
# mean   59.285714   126.666667     76.571429   97.761905         26.476190
# std    16.081489    19.885506     12.812382   26.929361          9.276956
# min    33.000000    87.000000     53.000000   41.000000         18.000000
# 25%    47.000000   115.000000     68.000000   86.000000         20.000000
# 50%    62.000000   125.000000     78.000000  102.000000         24.000000
# 75%    74.000000   137.000000     82.000000  109.000000         28.000000
# max    81.000000   175.000000    101.000000  161.000000         55.000000
#
#        oxygen_sat
# count   21.000000
# mean    92.380952
# std     10.897138
# min     47.000000
# 25%     94.000000
# 50%     95.000000
# 75%     96.000000
# max    100.000000

# %% [markdown]
# ##### Making the Correlation Table and Heatmap:

# %%
Patient.corr()
# Out:
#                        age  systolic_bp  diastolic_bp  heart_rate  \
# age               1.000000     0.122894     -0.091590   -0.223820
# systolic_bp       0.122894     1.000000      0.545567    0.368749
# diastolic_bp     -0.091590     0.545567      1.000000    0.369368
# heart_rate       -0.223820     0.368749      0.369368    1.000000
# respiratory_rate -0.024753     0.177077     -0.188337    0.491825
# oxygen_sat       -0.000082    -0.015075      0.397666    0.247042
#
#                   respiratory_rate  oxygen_sat
# age                      -0.024753   -0.000082
# systolic_bp               0.177077   -0.015075
# diastolic_bp             -0.188337    0.397666
# heart_rate                0.491825    0.247042
# respiratory_rate          1.000000   -0.429711
# oxygen_sat               -0.429711    1.000000

# %% [markdown]
# ##### Heatmap

# %%
fig=plt.figure(figsize=(15,10))
heat_map=Patient[['reason','meds','age','systolic_bp','diastolic_bp','heart_rate','respiratory_rate','oxygen_sat',]].corr(method='pearson')
cols=['reason','meds','age','systolic_bp','diastolic_bp','heart_rate','respiratory_rate','oxygen_sat']
axis=sns.heatmap(heat_map, annot=True, xticklabels=cols, yticklabels=cols )

# %% [markdown]
# ##### Getting Distributions:

# %%
Patient.describe()
# Out:
#              age  systolic_bp  diastolic_bp  heart_rate  respiratory_rate  \
# count  21.000000    21.000000     21.000000   21.000000         21.000000
# mean   59.285714   126.666667     76.571429   97.761905         26.476190
# std    16.081489    19.885506     12.812382   26.929361          9.276956
# min    33.000000    87.000000     53.000000   41.000000         18.000000
# 25%    47.000000   115.000000     68.000000   86.000000         20.000000
# 50%    62.000000   125.000000     78.000000  102.000000         24.000000
# 75%    74.000000   137.000000     82.000000  109.000000         28.000000
# max    81.000000   175.000000    101.000000  161.000000         55.000000
#
#        oxygen_sat
# count   21.000000
# mean    92.380952
# std     10.897138
# min     47.000000
# 25%     94.000000
# 50%     95.000000
# 75%     96.000000
# max    100.000000

# %%
Patient.groupby('heart_rate')['age'].sum().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='heart_rate'>

# %%
sns.displot(Patient.heart_rate,color='red', bins=25,kde=True)

# %%
sns.displot(Patient.respiratory_rate ,color='green', bins=25,kde=True)

# %%
sns.displot(Patient['oxygen_sat'],color='purple', bins=25,kde=True)

# %%
sns.displot(Patient['systolic_bp'],color='orange', bins=25,kde=True)

# %% [markdown]
# ##### Forming a scattplot showcasing Age/Oxygen_Saturation in High_Chance_of_Afib vs Low_Chance_of_Afib.

# %%
High_Chance_of_Afib = Patient.query("heart_rate >= 60")
Low_Chance_of_Afib = Patient.query("heart_rate <= 60")

# %%
High_Chance_of_Afib.plot.scatter(x="age",y="oxygen_sat")
# Out:
# <AxesSubplot:xlabel='age', ylabel='oxygen_sat'>

# %%
Low_Chance_of_Afib.plot.scatter(x="age",y="oxygen_sat", color = 'red')
# Out:
# <AxesSubplot:xlabel='age', ylabel='oxygen_sat'>

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)

ax1.scatter(High_Chance_of_Afib['age'], High_Chance_of_Afib['oxygen_sat'],s=10, c='b', marker="s", label='High_Chance_of_Afib')
ax1.scatter(Low_Chance_of_Afib['age'],Low_Chance_of_Afib['oxygen_sat'], s=10, c='r', marker="o", label='Low_Chance_of_Afib')
plt.legend(loc='upper left');
plt.show()

# %% [markdown]
# ##### Scattplot of systolic_blood_pressure vs Heart_rate

# %%
Patient.plot.scatter(x="systolic_bp",y="heart_rate", color="green")
# Out:
# <AxesSubplot:xlabel='systolic_bp', ylabel='heart_rate'>

# %% [markdown]
# ##### Heart_Rate Boxplot

# %%
bxt = Patient.boxplot(column = 'heart_rate')
bxt.set_title('Heart Rate Amongst 20 patients')
bxt.grid(False)

# %% [markdown]
# ##### Admission and comorbidities Bargraphs

# %%
Admission = Patient['reason'].groupby(Patient['reason']).count()
Admission
# Out:
# reason
# COVID-19                           11
# Cough                               1
# Fever                               1
# Pneumonia                           6
# Pneumonia due to COVID-19 virus     1
# Shortness of breath                 1
# Name: reason, dtype: int64

# %%
Admission.sort_values(ascending=False).plot(kind="barh",ylabel="Amount of Admissions",xlabel='Reason for Admission',figsize=(12,6))
# Out:
# <AxesSubplot:ylabel='Reason for Admission'>

# %%
Known_Illness = Patient['comorb'].groupby(Patient['comorb']).count()
Known_Illness
# Out:
# comorb
# Asthma, Other                                                                                                        2
# Chronic cardiac disease (not hypertension), Hypertension, Asthma, Obesity, Diabetes, Dementia any etiology, Other    1
# Chronic cardiac disease (not hypertension), Hypertension, Diabetes, Other                                            1
# Chronic cardiac disease (not hypertension), Hypertension, Other                                                      1
# Hypertension, Chronic pulmonary (lung) disease, Asthma, Diabetes, Other                                              1
# Hypertension, Chronic pulmonary (lung) disease, Other                                                                1
# Hypertension, Chronic renal, Diabetes, Other                                                                         1
# Hypertension, Diabetes, Other                                                                                        3
# Hypertension, Kidney disease, Other                                                                                  1
# Hypertension, Other                                                                                                  3
# Other                                                                                                                2
# Name: comorb, dtype: int64

# %% [markdown]
# ##### Known Illness besides Admission reason Pie Chart

# %%
Known_Illness.sort_values(ascending=False).plot(kind="pie",ylabel="",xlabel='Illness',figsize=(20,10)),plt.legend(loc='best')
# Out:
# (<AxesSubplot:>, <matplotlib.legend.Legend at 0x7fad19d2c4f0>)

# %% [markdown]
# ##### Pair Plot

# %%
Patient
# Out:
#                               reason  age     sex  \
# 504                         COVID-19   81    Male
# 444                        Pneumonia   79    Male
# 305                        Pneumonia   47    Male
# 112                         COVID-19   74  Female
# 53                         Pneumonia   34    Male
# 6                           COVID-19   50    Male
# 110                         COVID-19   68    Male
# 201                         COVID-19   65    Male
# 93                         Pneumonia   76    Male
# 84                          COVID-19   62    Male
# 150                         COVID-19   39    Male
# 300                        Pneumonia   40  Female
# 26                          COVID-19   33    Male
# 14                          COVID-19   58  Female
# 299                            Fever   76  Female
# 71                          COVID-19   63  Female
# 55                             Cough   77  Female
# 421  Pneumonia due to COVID-19 virus   36  Female
# 507                         COVID-19   73    Male
# 476              Shortness of breath   57  Female
# 500                        Pneumonia   57    Male
#
#                                                 comorb  \
# 504       Hypertension, Chronic renal, Diabetes, Other
# 444  Chronic cardiac disease (not hypertension), Hy...
# 305                      Hypertension, Diabetes, Other
# 112                                      Asthma, Other
# 53                                                None
# 6                                                 None
# 110                                Hypertension, Other
# 201                      Hypertension, Diabetes, Other
# 93                                 Hypertension, Other
# 84   Chronic cardiac disease (not hypertension), Hy...
# 150                                      Asthma, Other
# 300                                              Other
# 26                                               Other
# 14   Hypertension, Chronic pulmonary (lung) disease...
# 299  Chronic cardiac disease (not hypertension), Hy...
# 71                 Hypertension, Kidney disease, Other
# 55                                 Hypertension, Other
# 421                                               None
# 507                                               None
# 476                      Hypertension, Diabetes, Other
# 500  Hypertension, Chronic pulmonary (lung) disease...
#
#                                                   meds er_2_weeks  \
# 504  medications:SYNTHROID,dosage:75 mcg,frequency:...        Yes
# 444  medications:ELIQUIS,dosage:5,frequency:BID,med...         No
# 305  medications:NORVASC,dosage:10,frequency:OD,med...         No
# 112  medications:PANTOPRAZOLE,dosage:40,frequency:O...         No
# 53                                                None         No
# 6                                                 None         No
# 110  medications:PENNSAID,dosage:4 drops,frequency:...         No
# 201    medications:ROSUVASTATIN,dosage:20,frequency:OD         No
# 93   medications:TYLENOL EXTRA STRENGTH,dosage:500,...         No
# 84   medications:ACETYLSALICYLIC ACID  TAB,dosage:8...         No
# 150                                               None         No
# 300    medications:ESCITALOPRAM,dosage:10,frequency:OD         No
# 26                                                None         No
# 14   medications:ACETAMINOPHEN TAB ,dosage:650,freq...         No
# 299  medications:TYLENOL EXTRA STRENGTH,dosage:1000...         No
# 71   medications:ELIQUIS,dosage:5,frequency:BID,med...         No
# 55   medications:RABEPRAZOLE,dosage:20,frequency:OD...        Yes
# 421  medications:PRENATAL VITAMIN AND MINERAL SUPPL...        Yes
# 507                                               None        Yes
# 476  medications:LANTUS,dosage:70 units,frequency:O...         No
# 500  medications:COGENTIN TAB ,dosage:1,frequency:B...        Yes
#
#     admission_disposition  systolic_bp  diastolic_bp  heart_rate  \
# 504                  WARD          161            81         161
# 444                  WARD           87            66          41
# 305                  WARD          112            81         117
# 112                  WARD          113            71          84
# 53                   WARD          125            70         102
# 6                    WARD          149           100         130
# 110                  WARD          127            90          89
# 201                  WARD          126            80         108
# 93                   WARD          115            57         112
# 84                   WARD          108            66          72
# 150                  WARD          125            82         102
# 300                  WARD           99            68         109
# 26                   WARD          126            83         101
# 14                   WARD          142           101         102
# 299                  WARD          121            79         104
# 71                   WARD          137            59          97
# 55                   WARD          175            91          71
# 421                  WARD          127            76         128
# 507                  WARD          121            76          86
# 476                   ICU          122            53          47
# 500                  WARD          142            78          90
#
#      respiratory_rate  oxygen_sat
# 504                55          84
# 444                18         100
# 305                20          96
# 112                20          92
# 53                 18          96
# 6                  20          94
# 110                26          94
# 201                24          94
# 93                 28          96
# 84                 22          92
# 150                28          97
# 300                38          90
# 26                 22          96
# 14                 24          96
# 299                21          95
# 71                 28          96
# 55                 18          97
# 421                42          95
# 507                24          98
# 476                36          47
# 500                24          95

# %% [markdown]
# Had some strange errors here. I traced the problem back to some of the values of the hues only being present in one row of the Patient dataframe.

# %%
Patient.reason.groupby(Patient.reason).count()
# Out:
# reason
# COVID-19                           11
# Cough                               1
# Fever                               1
# Pneumonia                           6
# Pneumonia due to COVID-19 virus     1
# Shortness of breath                 1
# Name: reason, dtype: int64

# %%
pair_plot=sns.pairplot(Patient[0:20], hue="reason")

# %%
Patient.comorb.groupby(Patient.comorb).count()
# Out:
# comorb
# Asthma, Other                                                                                                        2
# Chronic cardiac disease (not hypertension), Hypertension, Asthma, Obesity, Diabetes, Dementia any etiology, Other    1
# Chronic cardiac disease (not hypertension), Hypertension, Diabetes, Other                                            1
# Chronic cardiac disease (not hypertension), Hypertension, Other                                                      1
# Hypertension, Chronic pulmonary (lung) disease, Asthma, Diabetes, Other                                              1
# Hypertension, Chronic pulmonary (lung) disease, Other                                                                1
# Hypertension, Chronic renal, Diabetes, Other                                                                         1
# Hypertension, Diabetes, Other                                                                                        3
# Hypertension, Kidney disease, Other                                                                                  1
# Hypertension, Other                                                                                                  3
# Other                                                                                                                2
# Name: comorb, dtype: int64

# %%
sns.set(style="ticks", color_codes=True)
sns.pairplot(Patient[0:20], hue='comorb')
